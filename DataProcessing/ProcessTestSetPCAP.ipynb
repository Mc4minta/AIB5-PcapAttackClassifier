# %% [markdown]
# <a href="https://colab.research.google.com/github/Mc4minta/AIB5-PcapAttackClassifier/blob/main/ProcessTestSetPCAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ⏲ CICFLOWMETER v.3

# %%
# !sudo apt-get install libpcap-dev # install libpcap-dev
# !wget https://codeberg.org/iortega/TCPDUMP_and_CICFlowMeter/archive/master:CICFlowMeters/CICFlowMeter-3.0.zip # download CICFlowMeter3.0.zip
# !unzip CICFlowMeter-3.0.zip -d CICFlowMeter-3.0 # Extract CICFlowMeter3.0.zip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libdbus-1-dev libpcap0.8 libpcap0.8-dev
# The following NEW packages will be installed:
#   libdbus-1-dev libpcap-dev libpcap0.8 libpcap0.8-dev
# 0 upgraded, 4 newly installed, 0 to remove and 34 not upgraded.
# Need to get 607 kB of archives.
# After this operation, 2,238 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8 amd64 1.10.1-4ubuntu1.22.04.1 [145 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-dev amd64 1.12.20-2ubuntu4.1 [188 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8-dev amd64 1.10.1-4ubuntu1.22.04.1 [270 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap-dev amd64 1.10.1-4ubuntu1.22.04.1 [3,326 B]
# Fetched 607 kB in 1s (1,019 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpcap0.8:amd64.
# (Reading database ... 126102 files and directories currently installed.)
# Preparing to unpack .../libpcap0.8_1.10.1-4ubuntu1.22.04.1_amd64.deb ...
# Unpacking libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../libdbus-1-dev_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package libpcap0.8-dev:amd64.
# Preparing to unpack .../libpcap0.8-dev_1.10.1-4ubuntu1.22.04.1_amd64.deb ...
# Unpacking libpcap0.8-dev:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Selecting previously unselected package libpcap-dev:amd64.
# Preparing to unpack .../libpcap-dev_1.10.1-4ubuntu1.22.04.1_amd64.deb ...
# Unpacking libpcap-dev:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Setting up libpcap0.8:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Setting up libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up libpcap0.8-dev:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Setting up libpcap-dev:amd64 (1.10.1-4ubuntu1.22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# --2025-05-27 04:01:48--  https://codeberg.org/iortega/TCPDUMP_and_CICFlowMeter/archive/master:CICFlowMeters/CICFlowMeter-3.0.zip
# Resolving codeberg.org (codeberg.org)... 217.197.84.140, 2a0a:4580:103f:c0de::1
# Connecting to codeberg.org (codeberg.org)|217.197.84.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15039922 (14M) [application/octet-stream]
# Saving to: ‘CICFlowMeter-3.0.zip’
#
# CICFlowMeter-3.0.zi 100%[===================>]  14.34M  7.27MB/s    in 2.0s
#
# 2025-05-27 04:01:51 (7.27 MB/s) - ‘CICFlowMeter-3.0.zip’ saved [15039922/15039922]
#
# Archive:  CICFlowMeter-3.0.zip
#    creating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/LICENSE.txt
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/README.md
#    creating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter.bat
#    creating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar
#    creating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/native/
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/native/jnetpcap-pcap100.dll
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/native/jnetpcap.dll
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/native/libjnetpcap-pcap100.so
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/native/libjnetpcap.so
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar
#   inflating: CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar

# %%
import os

# Define the directory paths
in_directory = 'data/in'
out_directory = 'data/out'

# Create the directories if they don't exist
os.makedirs(in_directory, exist_ok=True)
os.makedirs(out_directory, exist_ok=True)

print(f"Directories '{in_directory}' and '{out_directory}' created (if they didn't exist).")
# Out:
# Directories 'data/in' and 'data/out' created (if they didn't exist).

# %% [markdown]
# # ✅ DoS - GET PCAP FILES

# %%
import os
directory_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline'

# Check if the directory exists before listing its contents
if os.path.exists(directory_path):
  # List the contents of the directory
  contents = os.listdir(directory_path)

  # Print the contents
  for item in contents:
    print(item)
else:
  print(f"Directory not found: {directory_path}")
# Out:
# DoS.zip
# DDoS.zip
# PortScan.zip

# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/DoS.zip'
destination_directory = '/content/'

# Unzip the file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(destination_directory)
    print(f"'{zip_file_path}' unzipped to '{destination_directory}'.")
except FileNotFoundError:
    print(f"Error: Zip file not found at '{zip_file_path}'")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/DoS.zip' unzipped to '/content/'.

# %% [markdown]
# # ✅ DDoS - GET PCAP FILES

# %%
import os
directory_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline'

# Check if the directory exists before listing its contents
if os.path.exists(directory_path):
  # List the contents of the directory
  contents = os.listdir(directory_path)

  # Print the contents
  for item in contents:
    print(item)
else:
  print(f"Directory not found: {directory_path}")
# Out:
# DoS.zip
# DDoS.zip
# PortScan.zip

# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/DDoS.zip'
destination_directory = '/content/'

# Unzip the file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(destination_directory)
    print(f"'{zip_file_path}' unzipped to '{destination_directory}'.")
except FileNotFoundError:
    print(f"Error: Zip file not found at '{zip_file_path}'")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/DDoS.zip' unzipped to '/content/'.

# %% [markdown]
# # ✅ PortScan - GET PCAP FILES

# %%
import os
directory_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline'

# Check if the directory exists before listing its contents
if os.path.exists(directory_path):
  # List the contents of the directory
  contents = os.listdir(directory_path)

  # Print the contents
  for item in contents:
    print(item)
else:
  print(f"Directory not found: {directory_path}")
# Out:
# DoS.zip
# DDoS.zip
# PortScan.zip
# Benign.zip

# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/PortScan.zip'
destination_directory = '/content/'

# Unzip the file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(destination_directory)
    print(f"'{zip_file_path}' unzipped to '{destination_directory}'.")
except FileNotFoundError:
    print(f"Error: Zip file not found at '{zip_file_path}'")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/PortScan.zip' unzipped to '/content/'.

# %% [markdown]
# # ✅ Benign - GET PCAP FILES

# %%
import os
directory_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline'

# Check if the directory exists before listing its contents
if os.path.exists(directory_path):
  # List the contents of the directory
  contents = os.listdir(directory_path)

  # Print the contents
  for item in contents:
    print(item)
else:
  print(f"Directory not found: {directory_path}")
# Out:
# DoS.zip
# DDoS.zip
# PortScan.zip
# Benign.zip

# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/Benign.zip'
destination_directory = '/content/'

# Unzip the file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(destination_directory)
    print(f"'{zip_file_path}' unzipped to '{destination_directory}'.")
except FileNotFoundError:
    print(f"Error: Zip file not found at '{zip_file_path}'")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# '/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/TestsetForBaseline/Benign.zip' unzipped to '/content/'.

# %% [markdown]
# # ✅ DoS - Convert to .csv

# %%
import os

dos_directory = 'DoS'
pcap_files = [f for f in os.listdir(dos_directory) if f.endswith('.pcap')]

if pcap_files:
    print(f"Found {len(pcap_files)} .pcap files in '{dos_directory}':")
    for pcap_file in pcap_files:
        print(pcap_file)
else:
    print(f"No .pcap files found in '{dos_directory}'.")
# Out:
# Found 21 .pcap files in 'DoS':
# normal_DoS_2.pcap
# DDoS HTTP Flood Attacks.pcap
# normal_DoS_5.pcap
# http_slowloris.pcap
# normal_DoS_3.pcap
# DoS-GoldenEye_attack.pcap
# udp_dos.pcap
# GoldenEye.pcap
# DDoS ICMP Flood Attacks.pcap
# h4-DDoS-UDP.pcap
# hulk.pcap
# h4-DDoS-ICMP.pcap
# http_dos.pcap
# DDoS TCP SYN Flood Attacks.pcap
# SYN_DoS_pcap.pcap
# syn_tcp_dos.pcap
# normal_DoS_1.pcap
# normal_DoS_4.pcap
# h4-DDoS-SYN.pcap
# DoS-Hulk_attack.pcap
# DDoS UDP Flood Attacks.pcap

# %%
import os
import shutil
import subprocess

# Define the attack type directory (change this variable for different attack types)
attack_type = 'DoS' # You can change this to 'DDoS', 'PortScan', etc.

attack_directory = attack_type
data_in_directory = 'data/in'
data_out_directory = 'data/out'
csv_destination_directory = f'{attack_type}_csv'  # Directory for CSV files based on attack type
cicflowmeter_command = './CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter'

# Create the CSV destination directory if it doesn't exist
os.makedirs(csv_destination_directory, exist_ok=True)
print(f"Directory '{csv_destination_directory}' created (if it didn't exist).")

# Ensure the attack directory exists
if not os.path.exists(attack_directory):
    print(f"Error: Attack directory '{attack_directory}' not found.")
else:
    # Get the list of pcap files in the attack directory
    pcap_files = [f for f in os.listdir(attack_directory) if f.endswith('.pcap')]

    if pcap_files:
        print(f"Processing {len(pcap_files)} .pcap files in '{attack_directory}'...")
        for pcap_file in pcap_files:
            source_path = os.path.join(attack_directory, pcap_file)
            dest_in_path = os.path.join(data_in_directory, pcap_file)

            print(f"\nProcessing: {pcap_file}")

            # Step 2a: Move to data/in
            print(f"Moving '{pcap_file}' to '{data_in_directory}'...")
            shutil.move(source_path, data_in_directory)

            # Step 2b: Run CICFlowMeter
            print("Running CICFlowMeter...")
            try:
                # The CICFlowMeter command expects the input directory to be 'data/in' and outputs to 'data/out'
                subprocess.run([cicflowmeter_command], check=True, capture_output=True, text=True)
                print("CICFlowMeter finished successfully.")
            except subprocess.CalledProcessError as e:
                print(f"Error running CICFlowMeter: {e}")
                print(f"Stdout: {e.stdout}")
                print(f"Stderr: {e.stderr}")
                # Move the file back even if there was an error
                print(f"Moving '{pcap_file}' back to '{attack_directory}' due to error.")
                shutil.move(dest_in_path, attack_directory)
                continue # Move to the next file

            # Step 2c: Move results - Move CSV to DoS_csv and original pcap back to DoS
            print(f"Moving results from '{data_out_directory}' to '{csv_destination_directory}' and original pcap back to '{attack_directory}'...")
            output_files = os.listdir(data_out_directory)
            for output_file in output_files:
                # Check if the file is a CSV file generated by CICFlowMeter
                if output_file.endswith('_ISCX.csv'):
                    source_out_path = os.path.join(data_out_directory, output_file)
                    dest_csv_path = os.path.join(csv_destination_directory, output_file)
                    shutil.move(source_out_path, dest_csv_path)
                    print(f"Moved '{output_file}' to '{csv_destination_directory}'.")

            # Move the original pcap file back to the attack directory
            # We need to find the file in data/in after processing.
            # Assuming only one pcap file is in data/in at a time during the loop.
            processed_pcap_files_in_in = os.listdir(data_in_directory)
            for processed_pcap_file in processed_pcap_files_in_in:
                 if processed_pcap_file.endswith('.pcap'):
                    processed_in_path = os.path.join(data_in_directory, processed_pcap_file)
                    original_source_path = os.path.join(attack_directory, processed_pcap_file) # Construct original path
                    shutil.move(processed_in_path, original_source_path) # Move from data/in back to original location
                    print(f"Moved '{processed_pcap_file}' back to '{attack_directory}'.")


            # Step 2d: Clean up data/in and data/out
            print("Cleaning up temporary directories...")
            # Clean up any remaining files in data/out (should have been moved, but just in case)
            remaining_out_files = os.listdir(data_out_directory)
            for file in remaining_out_files:
                 os.remove(os.path.join(data_out_directory, file))

            print("Cleanup complete.")


        print(f"\nFinished processing all .pcap files in the '{attack_directory}' folder.")

    else:
        print(f"No .pcap files found in '{attack_directory}' to process.")
# Out:
# Directory 'DoS_csv' created (if it didn't exist).
# Processing 21 .pcap files in 'DoS'...
#
# Processing: normal_DoS_2.pcap
# Moving 'normal_DoS_2.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'normal_DoS_2_ISCX.csv' to 'DoS_csv'.
# Moved 'normal_DoS_2.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DDoS HTTP Flood Attacks.pcap
# Moving 'DDoS HTTP Flood Attacks.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'DDoS HTTP Flood Attacks_ISCX.csv' to 'DoS_csv'.
# Moved 'DDoS HTTP Flood Attacks.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DoS_5.pcap
# Moving 'normal_DoS_5.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'normal_DoS_5_ISCX.csv' to 'DoS_csv'.
# Moved 'normal_DoS_5.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: http_slowloris.pcap
# Moving 'http_slowloris.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'http_slowloris_ISCX.csv' to 'DoS_csv'.
# Moved 'http_slowloris.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DoS_3.pcap
# Moving 'normal_DoS_3.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'normal_DoS_3_ISCX.csv' to 'DoS_csv'.
# Moved 'normal_DoS_3.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DoS-GoldenEye_attack.pcap
# Moving 'DoS-GoldenEye_attack.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'DoS-GoldenEye_attack_ISCX.csv' to 'DoS_csv'.
# Moved 'DoS-GoldenEye_attack.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: udp_dos.pcap
# Moving 'udp_dos.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'udp_dos_ISCX.csv' to 'DoS_csv'.
# Moved 'udp_dos.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: GoldenEye.pcap
# Moving 'GoldenEye.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'GoldenEye_ISCX.csv' to 'DoS_csv'.
# Moved 'GoldenEye.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DDoS ICMP Flood Attacks.pcap
# Moving 'DDoS ICMP Flood Attacks.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/DDoS ICMP Flood Attacks.pcap
#
# Stderr: Exception in thread "DisposableGC" Exception in thread "main" java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.lang.Integer.toString(Integer.java:440)
# 	at java.base/java.lang.Integer.toString(Integer.java:143)
# 	at org.jnetpcap.packet.format.FormatUtils.asString(Unknown Source)
# 	at org.jnetpcap.packet.format.FormatUtils.asString(Unknown Source)
# 	at org.jnetpcap.packet.format.FormatUtils.ip(Unknown Source)
# 	at cic.cs.unb.ca.jnetpcap.BasicPacketInfo.getSourceIP(BasicPacketInfo.java:78)
# 	at cic.cs.unb.ca.jnetpcap.BasicPacketInfo.generateFlowId(BasicPacketInfo.java:65)
# 	at cic.cs.unb.ca.jnetpcap.BasicPacketInfo.getFlowId(BasicPacketInfo.java:143)
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:75)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
# java.lang.OutOfMemoryError: Java heap space
# 	at org.jnetpcap.nio.LinkSequence.iterator(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC.sortGenerations(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC.drainRefQueueLoop(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC$2.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# Moving 'DDoS ICMP Flood Attacks.pcap' back to 'DoS' due to error.
#
# Processing: h4-DDoS-UDP.pcap
# Moving 'h4-DDoS-UDP.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/h4-DDoS-UDP.pcap
#
# Stderr: Exception in thread "main" java.lang.OutOfMemoryError: Java heap space
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:117)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
#
# Moving 'h4-DDoS-UDP.pcap' back to 'DoS' due to error.
#
# Processing: hulk.pcap
# Moving 'hulk.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'hulk_ISCX.csv' to 'DoS_csv'.
# Moved 'hulk.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: h4-DDoS-ICMP.pcap
# Moving 'h4-DDoS-ICMP.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/h4-DDoS-ICMP.pcap
#
# Stderr: Exception in thread "main" java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.commons.math3.stat.descriptive.SummaryStatistics.<init>(SummaryStatistics.java:93)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.initParameters(BasicFlow.java:95)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.<init>(BasicFlow.java:73)
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:117)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
#
# Moving 'h4-DDoS-ICMP.pcap' back to 'DoS' due to error.
#
# Processing: http_dos.pcap
# Moving 'http_dos.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'http_dos_ISCX.csv' to 'DoS_csv'.
# Moved 'http_dos.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DDoS TCP SYN Flood Attacks.pcap
# Moving 'DDoS TCP SYN Flood Attacks.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/DDoS TCP SYN Flood Attacks.pcap
#
# Stderr: Exception in thread "main" Exception in thread "DisposableGC" java.lang.OutOfMemoryError: Java heap space
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.initParameters(BasicFlow.java:95)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.<init>(BasicFlow.java:73)
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:117)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
# java.lang.OutOfMemoryError: Java heap space
# 	at org.jnetpcap.nio.LinkSequence.iterator(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC.sortGenerations(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC.drainRefQueueLoop(Unknown Source)
# 	at org.jnetpcap.nio.DisposableGC$2.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# Moving 'DDoS TCP SYN Flood Attacks.pcap' back to 'DoS' due to error.
#
# Processing: SYN_DoS_pcap.pcap
# Moving 'SYN_DoS_pcap.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'SYN_DoS_pcap_ISCX.csv' to 'DoS_csv'.
# Moved 'SYN_DoS_pcap.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: syn_tcp_dos.pcap
# Moving 'syn_tcp_dos.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'syn_tcp_dos_ISCX.csv' to 'DoS_csv'.
# Moved 'syn_tcp_dos.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DoS_1.pcap
# Moving 'normal_DoS_1.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'normal_DoS_1_ISCX.csv' to 'DoS_csv'.
# Moved 'normal_DoS_1.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DoS_4.pcap
# Moving 'normal_DoS_4.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'normal_DoS_4_ISCX.csv' to 'DoS_csv'.
# Moved 'normal_DoS_4.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: h4-DDoS-SYN.pcap
# Moving 'h4-DDoS-SYN.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'h4-DDoS-SYN_ISCX.csv' to 'DoS_csv'.
# Moved 'h4-DDoS-SYN.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DoS-Hulk_attack.pcap
# Moving 'DoS-Hulk_attack.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DoS_csv' and original pcap back to 'DoS'...
# Moved 'DoS-Hulk_attack_ISCX.csv' to 'DoS_csv'.
# Moved 'DoS-Hulk_attack.pcap' back to 'DoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DDoS UDP Flood Attacks.pcap
# Moving 'DDoS UDP Flood Attacks.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/DDoS UDP Flood Attacks.pcap
#
# Stderr: Exception in thread "main" java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.commons.math3.stat.descriptive.SummaryStatistics.<init>(SummaryStatistics.java:69)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.initParameters(BasicFlow.java:91)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.<init>(BasicFlow.java:73)
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:117)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
#
# Moving 'DDoS UDP Flood Attacks.pcap' back to 'DoS' due to error.
#
# Finished processing all .pcap files in the 'DoS' folder.

# %%
! zip -r DoS_csv.zip DoS_csv
# Out:
#   adding: DoS_csv/ (stored 0%)
#   adding: DoS_csv/normal_DoS_3_ISCX.csv (deflated 78%)
#   adding: DoS_csv/DoS-GoldenEye_attack_ISCX.csv (deflated 76%)
#   adding: DoS_csv/udp_dos_ISCX.csv (deflated 81%)
#   adding: DoS_csv/normal_DoS_5_ISCX.csv (deflated 78%)
#   adding: DoS_csv/http_slowloris_ISCX.csv (deflated 83%)
#   adding: DoS_csv/h4-DDoS-SYN_ISCX.csv (deflated 66%)
#   adding: DoS_csv/hulk_ISCX.csv (deflated 72%)
#   adding: DoS_csv/normal_DoS_2_ISCX.csv (deflated 79%)
#   adding: DoS_csv/http_dos_ISCX.csv (deflated 75%)
#   adding: DoS_csv/normal_DoS_4_ISCX.csv (deflated 78%)
#   adding: DoS_csv/DDoS HTTP Flood Attacks_ISCX.csv (deflated 78%)
#   adding: DoS_csv/GoldenEye_ISCX.csv (deflated 75%)
#   adding: DoS_csv/DoS-Hulk_attack_ISCX.csv (deflated 75%)
#   adding: DoS_csv/syn_tcp_dos_ISCX.csv (deflated 73%)
#   adding: DoS_csv/normal_DoS_1_ISCX.csv (deflated 80%)
#   adding: DoS_csv/SYN_DoS_pcap_ISCX.csv (deflated 78%)

# %% [markdown]
# # ✅ DDoS - Convert to .csv

# %%
import os

dos_directory = 'DDoS'
pcap_files = [f for f in os.listdir(dos_directory) if f.endswith('.pcap')]

if pcap_files:
    print(f"Found {len(pcap_files)} .pcap files in '{dos_directory}':")
    for pcap_file in pcap_files:
        print(pcap_file)
else:
    print(f"No .pcap files found in '{dos_directory}'.")
# Out:
# Found 14 .pcap files in 'DDoS':
# normal_DDoS_4.pcap
# normal_DDoS_11.pcap
# mirai_ddos_http.pcap
# normal_DDoS_8.pcap
# normal_DDoS_9.pcap
# normal_DDoS_2.pcap
# normal_DDoS_6.pcap
# normal_DDoS_12.pcap
# normal_DDoS_1.pcap
# mirai_ddos_syn.pcap
# normal_DDoS_3.pcap
# normal_DDoS_5.pcap
# normal_DDoS_10.pcap
# normal_DDoS_7.pcap

# %%
import os
import shutil
import subprocess

# Define the attack type directory (change this variable for different attack types)
attack_type = 'DDoS' # You can change this to 'DDoS', 'PortScan', etc.

attack_directory = attack_type
data_in_directory = 'data/in'
data_out_directory = 'data/out'
csv_destination_directory = f'{attack_type}_csv'  # Directory for CSV files based on attack type
cicflowmeter_command = './CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter'

# Create the CSV destination directory if it doesn't exist
os.makedirs(csv_destination_directory, exist_ok=True)
print(f"Directory '{csv_destination_directory}' created (if it didn't exist).")

# Ensure the attack directory exists
if not os.path.exists(attack_directory):
    print(f"Error: Attack directory '{attack_directory}' not found.")
else:
    # Get the list of pcap files in the attack directory
    pcap_files = [f for f in os.listdir(attack_directory) if f.endswith('.pcap')]

    if pcap_files:
        print(f"Processing {len(pcap_files)} .pcap files in '{attack_directory}'...")
        for pcap_file in pcap_files:
            source_path = os.path.join(attack_directory, pcap_file)
            dest_in_path = os.path.join(data_in_directory, pcap_file)

            print(f"\nProcessing: {pcap_file}")

            # Step 2a: Move to data/in
            print(f"Moving '{pcap_file}' to '{data_in_directory}'...")
            shutil.move(source_path, data_in_directory)

            # Step 2b: Run CICFlowMeter
            print("Running CICFlowMeter...")
            try:
                # The CICFlowMeter command expects the input directory to be 'data/in' and outputs to 'data/out'
                subprocess.run([cicflowmeter_command], check=True, capture_output=True, text=True)
                print("CICFlowMeter finished successfully.")
            except subprocess.CalledProcessError as e:
                print(f"Error running CICFlowMeter: {e}")
                print(f"Stdout: {e.stdout}")
                print(f"Stderr: {e.stderr}")
                # Move the file back even if there was an error
                print(f"Moving '{pcap_file}' back to '{attack_directory}' due to error.")
                shutil.move(dest_in_path, attack_directory)
                continue # Move to the next file

            # Step 2c: Move results - Move CSV to DDoS_csv and original pcap back to DoS
            print(f"Moving results from '{data_out_directory}' to '{csv_destination_directory}' and original pcap back to '{attack_directory}'...")
            output_files = os.listdir(data_out_directory)
            for output_file in output_files:
                # Check if the file is a CSV file generated by CICFlowMeter
                if output_file.endswith('_ISCX.csv'):
                    source_out_path = os.path.join(data_out_directory, output_file)
                    dest_csv_path = os.path.join(csv_destination_directory, output_file)
                    shutil.move(source_out_path, dest_csv_path)
                    print(f"Moved '{output_file}' to '{csv_destination_directory}'.")

            # Move the original pcap file back to the attack directory
            # We need to find the file in data/in after processing.
            # Assuming only one pcap file is in data/in at a time during the loop.
            processed_pcap_files_in_in = os.listdir(data_in_directory)
            for processed_pcap_file in processed_pcap_files_in_in:
                 if processed_pcap_file.endswith('.pcap'):
                    processed_in_path = os.path.join(data_in_directory, processed_pcap_file)
                    original_source_path = os.path.join(attack_directory, processed_pcap_file) # Construct original path
                    shutil.move(processed_in_path, original_source_path) # Move from data/in back to original location
                    print(f"Moved '{processed_pcap_file}' back to '{attack_directory}'.")


            # Step 2d: Clean up data/in and data/out
            print("Cleaning up temporary directories...")
            # Clean up any remaining files in data/out (should have been moved, but just in case)
            remaining_out_files = os.listdir(data_out_directory)
            for file in remaining_out_files:
                 os.remove(os.path.join(data_out_directory, file))

            print("Cleanup complete.")


        print(f"\nFinished processing all .pcap files in the '{attack_directory}' folder.")

    else:
        print(f"No .pcap files found in '{attack_directory}' to process.")
# Out:
# Directory 'DDoS_csv' created (if it didn't exist).
# Processing 14 .pcap files in 'DDoS'...
#
# Processing: normal_DDoS_4.pcap
# Moving 'normal_DDoS_4.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_4_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_4.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_11.pcap
# Moving 'normal_DDoS_11.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_11_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_11.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: mirai_ddos_http.pcap
# Moving 'mirai_ddos_http.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'mirai_ddos_http_ISCX.csv' to 'DDoS_csv'.
# Moved 'mirai_ddos_http.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_8.pcap
# Moving 'normal_DDoS_8.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_8_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_8.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_9.pcap
# Moving 'normal_DDoS_9.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_9_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_9.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_2.pcap
# Moving 'normal_DDoS_2.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_2_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_2.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_6.pcap
# Moving 'normal_DDoS_6.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_6_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_6.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_12.pcap
# Moving 'normal_DDoS_12.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_12_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_12.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_1.pcap
# Moving 'normal_DDoS_1.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_1_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_1.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: mirai_ddos_syn.pcap
# Moving 'mirai_ddos_syn.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'mirai_ddos_syn_ISCX.csv' to 'DDoS_csv'.
# Moved 'mirai_ddos_syn.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_3.pcap
# Moving 'normal_DDoS_3.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_3_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_3.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_5.pcap
# Moving 'normal_DDoS_5.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_5_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_5.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_10.pcap
# Moving 'normal_DDoS_10.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_10_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_10.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_DDoS_7.pcap
# Moving 'normal_DDoS_7.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'DDoS_csv' and original pcap back to 'DDoS'...
# Moved 'normal_DDoS_7_ISCX.csv' to 'DDoS_csv'.
# Moved 'normal_DDoS_7.pcap' back to 'DDoS'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Finished processing all .pcap files in the 'DDoS' folder.

# %%
! zip -r DDoS_csv.zip DDoS_csv
# Out:
#   adding: DDoS_csv/ (stored 0%)
#   adding: DDoS_csv/normal_DDoS_8_ISCX.csv (deflated 87%)
#   adding: DDoS_csv/normal_DDoS_12_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_3_ISCX.csv (deflated 87%)
#   adding: DDoS_csv/normal_DDoS_9_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_6_ISCX.csv (deflated 87%)
#   adding: DDoS_csv/normal_DDoS_1_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_11_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/mirai_ddos_http_ISCX.csv (deflated 76%)
#   adding: DDoS_csv/mirai_ddos_syn_ISCX.csv (deflated 82%)
#   adding: DDoS_csv/normal_DDoS_2_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_4_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_5_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_7_ISCX.csv (deflated 86%)
#   adding: DDoS_csv/normal_DDoS_10_ISCX.csv (deflated 86%)

# %% [markdown]
# # ✅ PortScan - Convert to .csv

# %%
import os

dos_directory = 'PortScan'
pcap_files = [f for f in os.listdir(dos_directory) if f.endswith('.pcap')]

if pcap_files:
    print(f"Found {len(pcap_files)} .pcap files in '{dos_directory}':")
    for pcap_file in pcap_files:
        print(pcap_file)
else:
    print(f"No .pcap files found in '{dos_directory}'.")
# Out:
# Found 11 .pcap files in 'PortScan':
# normal_scanning6.pcap
# normal_scanning2.pcap
# normal_scanning5.pcap
# normal_scanning1.pcap
# normal_scanning3.pcap
# information_gathering.pcap
# nmap_fin.pcap
# normal_scanning4.pcap
# nmap_null.pcap
# portscan.pcap
# Port Scanning attack.pcap

# %%
import os
import shutil
import subprocess

# Define the attack type directory (change this variable for different attack types)
attack_type = 'PortScan' # You can change this to 'DDoS', 'PortScan', etc.

attack_directory = attack_type
data_in_directory = 'data/in'
data_out_directory = 'data/out'
csv_destination_directory = f'{attack_type}_csv'  # Directory for CSV files based on attack type
cicflowmeter_command = './CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter'

# Create the CSV destination directory if it doesn't exist
os.makedirs(csv_destination_directory, exist_ok=True)
print(f"Directory '{csv_destination_directory}' created (if it didn't exist).")

# Ensure the attack directory exists
if not os.path.exists(attack_directory):
    print(f"Error: Attack directory '{attack_directory}' not found.")
else:
    # Get the list of pcap files in the attack directory
    pcap_files = [f for f in os.listdir(attack_directory) if f.endswith('.pcap')]

    if pcap_files:
        print(f"Processing {len(pcap_files)} .pcap files in '{attack_directory}'...")
        for pcap_file in pcap_files:
            source_path = os.path.join(attack_directory, pcap_file)
            dest_in_path = os.path.join(data_in_directory, pcap_file)

            print(f"\nProcessing: {pcap_file}")

            # Step 2a: Move to data/in
            print(f"Moving '{pcap_file}' to '{data_in_directory}'...")
            shutil.move(source_path, data_in_directory)

            # Step 2b: Run CICFlowMeter
            print("Running CICFlowMeter...")
            try:
                # The CICFlowMeter command expects the input directory to be 'data/in' and outputs to 'data/out'
                subprocess.run([cicflowmeter_command], check=True, capture_output=True, text=True)
                print("CICFlowMeter finished successfully.")
            except subprocess.CalledProcessError as e:
                print(f"Error running CICFlowMeter: {e}")
                print(f"Stdout: {e.stdout}")
                print(f"Stderr: {e.stderr}")
                # Move the file back even if there was an error
                print(f"Moving '{pcap_file}' back to '{attack_directory}' due to error.")
                shutil.move(dest_in_path, attack_directory)
                continue # Move to the next file

            # Step 2c: Move results - Move CSV to PortScan_csv and original pcap back to DoS
            print(f"Moving results from '{data_out_directory}' to '{csv_destination_directory}' and original pcap back to '{attack_directory}'...")
            output_files = os.listdir(data_out_directory)
            for output_file in output_files:
                # Check if the file is a CSV file generated by CICFlowMeter
                if output_file.endswith('_ISCX.csv'):
                    source_out_path = os.path.join(data_out_directory, output_file)
                    dest_csv_path = os.path.join(csv_destination_directory, output_file)
                    shutil.move(source_out_path, dest_csv_path)
                    print(f"Moved '{output_file}' to '{csv_destination_directory}'.")

            # Move the original pcap file back to the attack directory
            # We need to find the file in data/in after processing.
            # Assuming only one pcap file is in data/in at a time during the loop.
            processed_pcap_files_in_in = os.listdir(data_in_directory)
            for processed_pcap_file in processed_pcap_files_in_in:
                 if processed_pcap_file.endswith('.pcap'):
                    processed_in_path = os.path.join(data_in_directory, processed_pcap_file)
                    original_source_path = os.path.join(attack_directory, processed_pcap_file) # Construct original path
                    shutil.move(processed_in_path, original_source_path) # Move from data/in back to original location
                    print(f"Moved '{processed_pcap_file}' back to '{attack_directory}'.")


            # Step 2d: Clean up data/in and data/out
            print("Cleaning up temporary directories...")
            # Clean up any remaining files in data/out (should have been moved, but just in case)
            remaining_out_files = os.listdir(data_out_directory)
            for file in remaining_out_files:
                 os.remove(os.path.join(data_out_directory, file))

            print("Cleanup complete.")


        print(f"\nFinished processing all .pcap files in the '{attack_directory}' folder.")

    else:
        print(f"No .pcap files found in '{attack_directory}' to process.")
# Out:
# Directory 'PortScan_csv' created (if it didn't exist).
# Processing 11 .pcap files in 'PortScan'...
#
# Processing: normal_scanning6.pcap
# Moving 'normal_scanning6.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning6_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning6.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_scanning2.pcap
# Moving 'normal_scanning2.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning2_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning2.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_scanning5.pcap
# Moving 'normal_scanning5.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning5_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning5.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_scanning1.pcap
# Moving 'normal_scanning1.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning1_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning1.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_scanning3.pcap
# Moving 'normal_scanning3.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning3_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning3.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: information_gathering.pcap
# Moving 'information_gathering.pcap' to 'data/in'...
# Running CICFlowMeter...
# Error running CICFlowMeter: Command '['./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter']' returned non-zero exit status 1.
# Stdout: run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# CLASSPATH: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/animal-sniffer-annotations-1.14.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/checker-compat-qual-2.0.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/CICFlowMeter-3.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-io-2.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-lang3-3.6.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/commons-math3-3.5.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/error_prone_annotations-2.1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/guava-23.6-jre.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/hamcrest-core-1.3.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/j2objc-annotations-1.1.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/java-cup-0.11a.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jfreechart-1.5.0.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jnetpcap-1.4.r1425-1g.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/jsr305-1.3.9.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/junit-4.12.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/log4j-1.2.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-api-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/slf4j-log4j12-1.7.25.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/tika-core-1.17.jar:/content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter/lib/weka-stable-3.6.14.jar
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter CICFlowMeter-V3 found: 1 Files.
# cic.cs.unb.ca.ifm.CICFlowMeter
# cic.cs.unb.ca.ifm.CICFlowMeter Working on... /content/data/in/information_gathering.pcap
#
# Stderr: Exception in thread "main" java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.commons.math3.stat.descriptive.SummaryStatistics.<init>(SummaryStatistics.java:69)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.initParameters(BasicFlow.java:89)
# 	at cic.cs.unb.ca.jnetpcap.BasicFlow.<init>(BasicFlow.java:73)
# 	at cic.cs.unb.ca.jnetpcap.FlowGenerator.addPacket(FlowGenerator.java:117)
# 	at cic.cs.unb.ca.ifm.CICFlowMeter.main(CICFlowMeter.java:106)
#
# Moving 'information_gathering.pcap' back to 'PortScan' due to error.
#
# Processing: nmap_fin.pcap
# Moving 'nmap_fin.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'nmap_fin_ISCX.csv' to 'PortScan_csv'.
# Moved 'nmap_fin.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_scanning4.pcap
# Moving 'normal_scanning4.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'normal_scanning4_ISCX.csv' to 'PortScan_csv'.
# Moved 'normal_scanning4.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: nmap_null.pcap
# Moving 'nmap_null.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'nmap_null_ISCX.csv' to 'PortScan_csv'.
# Moved 'nmap_null.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: portscan.pcap
# Moving 'portscan.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'portscan_ISCX.csv' to 'PortScan_csv'.
# Moved 'portscan.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Port Scanning attack.pcap
# Moving 'Port Scanning attack.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'PortScan_csv' and original pcap back to 'PortScan'...
# Moved 'Port Scanning attack_ISCX.csv' to 'PortScan_csv'.
# Moved 'Port Scanning attack.pcap' back to 'PortScan'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Finished processing all .pcap files in the 'PortScan' folder.

# %%
! zip -r PortScan_csv.zip PortScan_csv
# Out:
#   adding: PortScan_csv/ (stored 0%)
#   adding: PortScan_csv/normal_scanning3_ISCX.csv (deflated 87%)
#   adding: PortScan_csv/Port Scanning attack_ISCX.csv (deflated 94%)
#   adding: PortScan_csv/nmap_null_ISCX.csv (deflated 95%)
#   adding: PortScan_csv/portscan_ISCX.csv (deflated 66%)
#   adding: PortScan_csv/normal_scanning4_ISCX.csv (deflated 87%)
#   adding: PortScan_csv/normal_scanning6_ISCX.csv (deflated 87%)
#   adding: PortScan_csv/normal_scanning1_ISCX.csv (deflated 84%)
#   adding: PortScan_csv/normal_scanning2_ISCX.csv (deflated 87%)
#   adding: PortScan_csv/normal_scanning5_ISCX.csv (deflated 87%)
#   adding: PortScan_csv/nmap_fin_ISCX.csv (deflated 93%)

# %% [markdown]
# # ✅ Benign - Convert to .csv

# %%
import os

dos_directory = 'Benign'
pcap_files = [f for f in os.listdir(dos_directory) if f.endswith('.pcap')]

if pcap_files:
    print(f"Found {len(pcap_files)} .pcap files in '{dos_directory}':")
    for pcap_file in pcap_files:
        print(pcap_file)
else:
    print(f"No .pcap files found in '{dos_directory}'.")
# Out:
# Found 21 .pcap files in 'Benign':
# Normal-h3_2.pcap
# Normal-h3_12.pcap
# normal_3.pcap
# Normal-h3_6.pcap
# normal_13.pcap
# DoS-GoldenEye_benign.pcap
# Normal-h3_3.pcap
# normal_10.pcap
# Normal-h3_5.pcap
# Normal-h3_10.pcap
# DoS-Hulk_benign.pcap
# Normal-h3_11.pcap
# normal_2.pcap
# normal_4.pcap
# Normal-h3_4.pcap
# Normal-h3_9.pcap
# Normal-h3_8.pcap
# normal_1.pcap
# normal_11.pcap
# normal_12.pcap
# Normal-h3_1.pcap

# %%
import os
import shutil
import subprocess

# Define the attack type directory (change this variable for different attack types)
attack_type = 'Benign' # You can change this to 'DDoS', 'PortScan', etc.

attack_directory = attack_type
data_in_directory = 'data/in'
data_out_directory = 'data/out'
csv_destination_directory = f'{attack_type}_csv'  # Directory for CSV files based on attack type
cicflowmeter_command = './CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter'

# Create the CSV destination directory if it doesn't exist
os.makedirs(csv_destination_directory, exist_ok=True)
print(f"Directory '{csv_destination_directory}' created (if it didn't exist).")

# Ensure the attack directory exists
if not os.path.exists(attack_directory):
    print(f"Error: Attack directory '{attack_directory}' not found.")
else:
    # Get the list of pcap files in the attack directory
    pcap_files = [f for f in os.listdir(attack_directory) if f.endswith('.pcap')]

    if pcap_files:
        print(f"Processing {len(pcap_files)} .pcap files in '{attack_directory}'...")
        for pcap_file in pcap_files:
            source_path = os.path.join(attack_directory, pcap_file)
            dest_in_path = os.path.join(data_in_directory, pcap_file)

            print(f"\nProcessing: {pcap_file}")

            # Step 2a: Move to data/in
            print(f"Moving '{pcap_file}' to '{data_in_directory}'...")
            shutil.move(source_path, data_in_directory)

            # Step 2b: Run CICFlowMeter
            print("Running CICFlowMeter...")
            try:
                # The CICFlowMeter command expects the input directory to be 'data/in' and outputs to 'data/out'
                subprocess.run([cicflowmeter_command], check=True, capture_output=True, text=True)
                print("CICFlowMeter finished successfully.")
            except subprocess.CalledProcessError as e:
                print(f"Error running CICFlowMeter: {e}")
                print(f"Stdout: {e.stdout}")
                print(f"Stderr: {e.stderr}")
                # Move the file back even if there was an error
                print(f"Moving '{pcap_file}' back to '{attack_directory}' due to error.")
                shutil.move(dest_in_path, attack_directory)
                continue # Move to the next file

            # Step 2c: Move results - Move CSV to Benign_csv and original pcap back to DoS
            print(f"Moving results from '{data_out_directory}' to '{csv_destination_directory}' and original pcap back to '{attack_directory}'...")
            output_files = os.listdir(data_out_directory)
            for output_file in output_files:
                # Check if the file is a CSV file generated by CICFlowMeter
                if output_file.endswith('_ISCX.csv'):
                    source_out_path = os.path.join(data_out_directory, output_file)
                    dest_csv_path = os.path.join(csv_destination_directory, output_file)
                    shutil.move(source_out_path, dest_csv_path)
                    print(f"Moved '{output_file}' to '{csv_destination_directory}'.")

            # Move the original pcap file back to the attack directory
            # We need to find the file in data/in after processing.
            # Assuming only one pcap file is in data/in at a time during the loop.
            processed_pcap_files_in_in = os.listdir(data_in_directory)
            for processed_pcap_file in processed_pcap_files_in_in:
                 if processed_pcap_file.endswith('.pcap'):
                    processed_in_path = os.path.join(data_in_directory, processed_pcap_file)
                    original_source_path = os.path.join(attack_directory, processed_pcap_file) # Construct original path
                    shutil.move(processed_in_path, original_source_path) # Move from data/in back to original location
                    print(f"Moved '{processed_pcap_file}' back to '{attack_directory}'.")


            # Step 2d: Clean up data/in and data/out
            print("Cleaning up temporary directories...")
            # Clean up any remaining files in data/out (should have been moved, but just in case)
            remaining_out_files = os.listdir(data_out_directory)
            for file in remaining_out_files:
                 os.remove(os.path.join(data_out_directory, file))

            print("Cleanup complete.")


        print(f"\nFinished processing all .pcap files in the '{attack_directory}' folder.")

    else:
        print(f"No .pcap files found in '{attack_directory}' to process.")
# Out:
# Directory 'Benign_csv' created (if it didn't exist).
# Processing 21 .pcap files in 'Benign'...
#
# Processing: Normal-h3_2.pcap
# Moving 'Normal-h3_2.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_2_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_2.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_12.pcap
# Moving 'Normal-h3_12.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_12_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_12.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_3.pcap
# Moving 'normal_3.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_3_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_3.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_6.pcap
# Moving 'Normal-h3_6.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_6_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_6.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_13.pcap
# Moving 'normal_13.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_13_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_13.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DoS-GoldenEye_benign.pcap
# Moving 'DoS-GoldenEye_benign.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'DoS-GoldenEye_benign_ISCX.csv' to 'Benign_csv'.
# Moved 'DoS-GoldenEye_benign.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_3.pcap
# Moving 'Normal-h3_3.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_3_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_3.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_10.pcap
# Moving 'normal_10.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_10_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_10.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_5.pcap
# Moving 'Normal-h3_5.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_5_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_5.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_10.pcap
# Moving 'Normal-h3_10.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_10_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_10.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: DoS-Hulk_benign.pcap
# Moving 'DoS-Hulk_benign.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'DoS-Hulk_benign_ISCX.csv' to 'Benign_csv'.
# Moved 'DoS-Hulk_benign.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_11.pcap
# Moving 'Normal-h3_11.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_11_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_11.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_2.pcap
# Moving 'normal_2.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_2_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_2.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_4.pcap
# Moving 'normal_4.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_4_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_4.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_4.pcap
# Moving 'Normal-h3_4.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_4_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_4.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_9.pcap
# Moving 'Normal-h3_9.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_9_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_9.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_8.pcap
# Moving 'Normal-h3_8.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_8_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_8.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_1.pcap
# Moving 'normal_1.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_1_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_1.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_11.pcap
# Moving 'normal_11.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_11_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_11.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: normal_12.pcap
# Moving 'normal_12.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'normal_12_ISCX.csv' to 'Benign_csv'.
# Moved 'normal_12.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Processing: Normal-h3_1.pcap
# Moving 'Normal-h3_1.pcap' to 'data/in'...
# Running CICFlowMeter...
# CICFlowMeter finished successfully.
# Moving results from 'data/out' to 'Benign_csv' and original pcap back to 'Benign'...
# Moved 'Normal-h3_1_ISCX.csv' to 'Benign_csv'.
# Moved 'Normal-h3_1.pcap' back to 'Benign'.
# Cleaning up temporary directories...
# Cleanup complete.
#
# Finished processing all .pcap files in the 'Benign' folder.

# %%
! zip -r Benign_csv.zip Benign_csv
# Out:
#   adding: Benign_csv/ (stored 0%)
#   adding: Benign_csv/DoS-Hulk_benign_ISCX.csv (deflated 75%)
#   adding: Benign_csv/Normal-h3_2_ISCX.csv (deflated 75%)
#   adding: Benign_csv/normal_3_ISCX.csv (deflated 85%)
#   adding: Benign_csv/normal_1_ISCX.csv (deflated 83%)
#   adding: Benign_csv/DoS-GoldenEye_benign_ISCX.csv (deflated 75%)
#   adding: Benign_csv/Normal-h3_1_ISCX.csv (deflated 76%)
#   adding: Benign_csv/normal_4_ISCX.csv (deflated 83%)
#   adding: Benign_csv/Normal-h3_10_ISCX.csv (deflated 74%)
#   adding: Benign_csv/normal_13_ISCX.csv (deflated 82%)
#   adding: Benign_csv/Normal-h3_12_ISCX.csv (deflated 76%)
#   adding: Benign_csv/normal_2_ISCX.csv (deflated 85%)
#   adding: Benign_csv/normal_10_ISCX.csv (deflated 72%)
#   adding: Benign_csv/Normal-h3_8_ISCX.csv (deflated 74%)
#   adding: Benign_csv/Normal-h3_5_ISCX.csv (deflated 74%)
#   adding: Benign_csv/Normal-h3_11_ISCX.csv (deflated 74%)
#   adding: Benign_csv/Normal-h3_3_ISCX.csv (deflated 71%)
#   adding: Benign_csv/Normal-h3_6_ISCX.csv (deflated 74%)
#   adding: Benign_csv/Normal-h3_9_ISCX.csv (deflated 74%)
#   adding: Benign_csv/normal_11_ISCX.csv (deflated 73%)
#   adding: Benign_csv/Normal-h3_4_ISCX.csv (deflated 73%)
#   adding: Benign_csv/normal_12_ISCX.csv (deflated 74%)
