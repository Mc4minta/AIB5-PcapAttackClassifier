# %% [markdown]
# <a href="https://colab.research.google.com/github/Mc4minta/AIB5-PcapAttackClassifier/blob/main/Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.6.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading scapy-2.6.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: scapy
# Successfully installed scapy-2.6.1

# %% [markdown]
# # TPs-ESIR-S9 Original

# %%
# Necessary imports
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from scapy.all import *
import pandas as pd # Add pandas here as it's used in display functions
import os # Import the os module

# Model and Tokenizer Loading
tokenizer = AutoTokenizer.from_pretrained("rdpahalavan/bert-network-packet-flow-header-payload")
model = AutoModelForSequenceClassification.from_pretrained("rdpahalavan/bert-network-packet-flow-header-payload")

# Classes
classes = [
 'Analysis',
 'Backdoor',
 'Bot',
 'DDoS',
 'DoS',
 'DoS GoldenEye',
 'DoS Hulk',
 'DoS SlowHTTPTest',
 'DoS Slowloris',
 'Exploits',
 'FTP Patator',
 'Fuzzers',
 'Generic',
 'Heartbleed',
 'Infiltration',
 'Normal',
 'Port Scan',
 'Reconnaissance',
 'SSH Patator',
 'Shellcode',
 'Web Attack - Brute Force',
 'Web Attack - SQL Injection',
 'Web Attack - XSS',
 'Worms']

# Device setup
device = torch.device("cpu")
model = model.to(device)

# Initialize dictionaries and lists for packet analysis.
packets_brief = {}
forward_packets = {}
backward_packets = {}
protocols = []
protocol_counts = {}

def processing_packet_conversion(packet):
    # Clone the packet for processing without modifying the original.
    packet_2 = packet

    while packet_2:
        # Extract and count protocol layers in the packet.
        layer = packet_2[0]
        if layer.name not in protocol_counts:
            protocol_counts[layer.name] = 0
        else:
            protocol_counts[layer.name] += 1
        protocols.append(layer.name)

        # Break if there are no more payload layers.
        if not layer.payload:
            break
        packet_2 = layer.payload

    # Extract relevant information for feature creation.
    src_ip = packet[IP].src
    dst_ip = packet[IP].dst
    src_port = packet.sport
    dst_port = packet.dport
    ip_length = len(packet[IP])
    ip_ttl = packet[IP].ttl
    ip_tos = packet[IP].tos
    tcp_data_offset = packet[TCP].dataofs
    tcp_flags = packet[TCP].flags

    # Process payload content and create a feature string.
    payload_bytes = bytes(packet.payload)
    payload_length = len(payload_bytes)
    payload_content = payload_bytes.decode('utf-8', 'replace')
    payload_decimal = ' '.join(str(byte) for byte in payload_bytes)
    final_data = "0" + " " + "0" + " " + "195" + " " + "-1" + " " + str(src_port) + " " + str(dst_port) + " " + str(ip_length) + " " + str(payload_length) + " " + str(ip_ttl) + " " + str(ip_tos) + " " + str(tcp_data_offset) + " " + str(int(tcp_flags)) + " " + "-1" + " " + str(payload_decimal)
    return final_data


# Prediction function
text_data = []

def predictingRowsCategory(file_path, filter):
  packets_brief.clear()  # Clear the dictionary tracking packet briefs.

  packets_nbr = 0  # Initialize packet counter.
  with PcapReader(file_path) as pcap:  # Iterate through packets in the pcap file.
    for pkt in pcap:
      if IP in pkt :  # Check for IPv4 packets
        if TCP in pkt:

          input_line = processing_packet_conversion(pkt)  # Process packet data
          if input_line is not None:

            truncated_line = input_line[:1024]  # Limit input length
            tokens = tokenizer(truncated_line, return_tensors="pt")  # Tokenize input
            tokens = {key: value.to(device) for key, value in tokens.items()} # Move tokens to device
            outputs = model(**tokens)  # Pass tokens through the model
            logits = outputs.logits
            probabilities = logits.softmax(dim=1)  # Calculate class probabilities
            predicted_class = torch.argmax(probabilities, dim=1).item()  # Get predicted class index

            predictedAttack = classes[predicted_class]  # Map index to corresponding attack class

            if predictedAttack != "Normal":
              # Update or add count for non-normal packets in packets_brief dictionary
              if predictedAttack not in packets_brief :
                packets_brief[predictedAttack] = 1
              else :
                packets_brief[predictedAttack] += 1

            # Print prediction details
            print("Predicted class:", predicted_class)
            print("predicted class is : ", classes[predicted_class])
            print("Class probabilities:", probabilities.tolist())

          packets_nbr += 1  # Increment packet counter
  return packets_nbr

# %%
import pandas as pd

def display_detected_attack_summary(packets_brief, total_packets):
    """
    Displays a summary table of predicted attack types and their percentages
    out of the total packets processed.

    Args:
        packets_brief (dict): A dictionary with predicted classes and their counts.
        total_packets (int): The total number of packets processed.
    """
    if not packets_brief:
        print("No packet data to display.")
        return

    attack_data = []
    # Include all classes from packets_brief
    data_to_display = packets_brief
    total_for_percentage = total_packets
    table_title = "Summary of Predicted Packet Classes:"
    total_row_label = 'Total Packets Processed'


    if total_for_percentage == 0:
         print("No packets were processed.")
         return

    for attack, count in data_to_display.items():
        percentage = (count / total_for_percentage) * 100
        attack_data.append({'Attack Type': attack, 'Packet Count': count, 'Percentage (%)': percentage})

    attack_percentages_df = pd.DataFrame(attack_data)

    attack_percentages_df = attack_percentages_df.sort_values(by='Percentage (%)', ascending=False)
    total_row = pd.DataFrame([{'Attack Type': total_row_label, 'Packet Count': total_for_percentage, 'Percentage (%)': 100.0}])
    attack_percentages_df = pd.concat([attack_percentages_df, total_row], ignore_index=True)


    print(table_title)
    display(attack_percentages_df)

# %%
total_packets = predictingRowsCategory("/content/ftpbrute-ubuntu.pcap", b"")
# Out:
# Streaming output truncated to the last 5000 lines.
# predicted class is :  Normal
# Class probabilities: [[1.0251880724551632e-12, 1.3259894050821064e-11, 9.166759795675716e-09, 1.276132053362744e-07, 9.730351990810959e-08, 1.4621384103463697e-09, 3.376834101231907e-08, 3.168377915585552e-08, 5.576389905392887e-10, 2.5807612047401562e-08, 6.463586714744451e-07, 9.728592931246283e-11, 6.121830153915653e-09, 7.723751416222058e-09, 6.279362030348068e-10, 0.999998927116394, 5.981068085247898e-09, 1.1803816257760502e-10, 1.7372070715282462e-07, 1.4523864749760307e-11, 2.4447850410780347e-09, 1.0063404970450662e-10, 1.0078705869887017e-08, 7.343653463109945e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.9160532535589248e-12, 1.57989558935423e-11, 9.016129176586674e-09, 3.925426597106707e-07, 1.244881531192732e-07, 3.5087404093303576e-09, 4.349526605551546e-08, 5.9058574919390594e-08, 1.3769020368314955e-09, 2.9528429479341867e-08, 1.7059229548976873e-06, 1.4028536665655622e-10, 8.61946247709966e-09, 8.113405947085539e-09, 1.1978761316200348e-09, 0.9999973773956299, 7.038368110556803e-09, 1.4093116951219287e-10, 3.0675690254611254e-07, 2.473219719301145e-11, 5.912741407598787e-09, 1.3814679955537201e-10, 1.7877475499972206e-08, 1.0768944069816655e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.181103711146775e-11, 2.065113913207739e-10, 3.484273491949352e-08, 8.600326509622391e-06, 3.1813428336135985e-07, 1.0684392691473477e-05, 9.887329724733718e-06, 0.00011544791050255299, 1.0366684932705539e-07, 1.5487927385038347e-07, 6.243445386644453e-05, 1.284389217204307e-08, 6.391811524508739e-08, 6.826901000067664e-08, 1.5822653409713894e-08, 0.9997857213020325, 8.779672953096451e-07, 9.865214201099093e-10, 6.624066486438096e-07, 1.2415256323006219e-10, 3.196629904778092e-06, 6.3236944569666775e-09, 1.638487447053194e-06, 1.98721039623706e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.066374961423977e-12, 1.732909996055021e-11, 8.433195475276989e-09, 1.0341621958787073e-07, 1.694846361033342e-07, 1.204012556321743e-09, 1.7522564732530554e-08, 1.1755009410308048e-08, 6.968077226332525e-10, 2.5308647622068747e-08, 3.5350120697330567e-07, 1.1115258019556151e-10, 6.988831291465658e-09, 3.50069151444643e-09, 7.606426044581838e-10, 0.9999991655349731, 8.417976538055427e-09, 9.92624732409908e-11, 1.8638101551005093e-07, 1.4675127432695056e-11, 2.2660782139638513e-09, 8.30127078188525e-11, 9.478079654456906e-09, 6.390788592769425e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.41178388024621e-12, 2.3446241476099416e-11, 7.475178698257423e-09, 3.5961244293503114e-07, 1.574532717540933e-07, 4.15556700161801e-09, 5.903596544953871e-08, 1.0862311938808489e-07, 1.7827114229262975e-09, 4.0924227562300075e-08, 6.678375484625576e-06, 1.960487883145845e-10, 1.1369538199801354e-08, 1.2575358532274095e-08, 1.3574212864853052e-09, 0.9999921321868896, 1.2594608911342675e-08, 1.0066005667885847e-10, 4.004687355063652e-07, 4.1141978712744276e-11, 1.3134695997507606e-08, 1.3092836537165198e-10, 2.9895613096186935e-08, 1.3673390197865842e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.367165708241914e-12, 2.595919659786894e-11, 7.0392820461506744e-09, 5.437129857455147e-07, 1.416499912920699e-07, 3.910029633402701e-09, 5.569223660017997e-08, 8.877097457116179e-08, 1.3363479212102902e-09, 3.631851441809886e-08, 4.8481597332283854e-06, 2.0622642482592823e-10, 1.0408545136897374e-08, 1.529993554072462e-08, 1.5482581883219382e-09, 0.9999936819076538, 1.3105862173290461e-08, 1.3220233241462154e-10, 4.633185994862288e-07, 3.262073597354309e-11, 1.0594681576492349e-08, 1.269007954274315e-10, 2.8736064194845312e-08, 1.221026335596065e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.890057771750109e-12, 1.571103316888589e-11, 9.375133558364723e-09, 3.592165001009562e-07, 1.3040268243003084e-07, 3.2290643492416393e-09, 3.9058658529711465e-08, 5.3544415123951694e-08, 1.2855163600278274e-09, 3.00286480126033e-08, 1.4420276102100615e-06, 1.3771409013152436e-10, 9.010648227558704e-09, 7.881233443640667e-09, 1.1798720889188985e-09, 0.9999977350234985, 6.5707643770451796e-09, 1.42537551206523e-10, 2.982886826430331e-07, 2.4685642419086662e-11, 5.2997748412053625e-09, 1.3793621800317624e-10, 1.645842218067628e-08, 1.0592732940795102e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.4302311465301818e-12, 2.3624900646890268e-11, 7.70120589521639e-09, 3.9137805174505047e-07, 1.34661220840826e-07, 4.334841818831592e-09, 8.084587932444265e-08, 7.954648850727608e-08, 1.7190727730209687e-09, 3.4367918289035515e-08, 2.980926183226984e-06, 1.9964264963423517e-10, 8.65174776265576e-09, 1.5384596707690434e-08, 1.1875325167665096e-09, 0.9999958276748657, 1.4927168834333315e-08, 1.122177420431747e-10, 4.3332920540706255e-07, 2.8181082467604313e-11, 1.3062815718001275e-08, 1.8170667748229619e-10, 3.179149743459675e-08, 1.5378978646118924e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.915645305362929e-11, 2.9392951961249025e-10, 1.2778998836893152e-07, 0.00011622962483670563, 9.462242474000959e-07, 4.018895367607911e-07, 6.182311267366458e-07, 8.610163786215708e-05, 4.9064050600122755e-09, 3.515225159844704e-07, 1.175654415419558e-05, 6.586004985820182e-08, 1.087994334625364e-07, 2.6168418116867542e-05, 8.383377547716009e-09, 0.9997562766075134, 2.040693942717553e-07, 3.1826630220166408e-09, 2.7870800067830714e-07, 4.3101071323103923e-11, 2.3583140773553168e-07, 5.401865177390164e-09, 1.376211855586007e-07, 3.52876949882841e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.3403681336658932e-12, 2.457232854691238e-11, 7.342542573951505e-09, 6.40158702935878e-07, 1.25052409316595e-07, 4.445889878468279e-09, 6.291071485975408e-08, 8.033106979610238e-08, 1.3949591481932089e-09, 3.009750670912581e-08, 3.03163574244536e-06, 1.8826258607607116e-10, 9.089877295309634e-09, 1.429089468985012e-08, 1.4592775876565156e-09, 0.9999954700469971, 1.134970784022471e-08, 1.594454568376591e-10, 4.760754848120996e-07, 2.5746618378952313e-11, 1.0559274343791003e-08, 1.588102011007564e-10, 2.872674542686582e-08, 1.2267056814785349e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.1934064807493936e-12, 1.6641462513566907e-11, 1.3902760720441165e-08, 1.925346396092209e-06, 8.640990500907719e-08, 4.6388453078805014e-09, 1.409498366911066e-07, 5.062228751739895e-07, 2.5971187422868525e-09, 2.289984024628211e-08, 3.7260488738866115e-07, 1.4798182124131642e-10, 6.549061737359807e-09, 1.0017111407023549e-07, 1.1764507146239112e-09, 0.9999966621398926, 7.306047766775237e-09, 1.0781061460241048e-10, 1.4041987128621258e-07, 6.044902859519974e-12, 1.4648350976642632e-08, 5.589880225365107e-10, 2.1295671004395444e-08, 1.051714687561045e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.1934064807493936e-12, 1.6641462513566907e-11, 1.3902760720441165e-08, 1.925346396092209e-06, 8.640990500907719e-08, 4.6388453078805014e-09, 1.409498366911066e-07, 5.062228751739895e-07, 2.5971187422868525e-09, 2.289984024628211e-08, 3.7260488738866115e-07, 1.4798182124131642e-10, 6.549061737359807e-09, 1.0017111407023549e-07, 1.1764507146239112e-09, 0.9999966621398926, 7.306047766775237e-09, 1.0781061460241048e-10, 1.4041987128621258e-07, 6.044902859519974e-12, 1.4648350976642632e-08, 5.589880225365107e-10, 2.1295671004395444e-08, 1.051714687561045e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.640521885004631e-10, 4.455336655162512e-10, 7.268544521821241e-08, 9.742080874275416e-05, 4.3686358708328044e-07, 5.176250397198601e-07, 6.860698249511188e-06, 9.106161996896844e-06, 2.555224654088306e-08, 2.4487044925081136e-07, 6.74165494274348e-06, 9.68450830640677e-09, 6.431962873421071e-08, 1.1892171869476442e-06, 7.512525712627394e-09, 0.9998717308044434, 5.748239004788047e-07, 4.484701499052335e-09, 4.52228005087818e-06, 5.993913004820328e-11, 2.235255180949025e-07, 6.04554051264472e-09, 3.6969007055631664e-07, 2.8465967361057665e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.395348751102702e-11, 8.418359065398562e-11, 6.725692003328732e-08, 0.00010005643707700074, 1.295449578719854e-07, 2.5204999474226497e-06, 9.152543498203158e-06, 0.00020891075837425888, 4.3730619125881276e-08, 5.366834798792297e-08, 1.7680054952506907e-05, 3.83112963575627e-09, 1.0240106540493343e-08, 1.4163749995077524e-07, 9.842350046085357e-09, 0.9996565580368042, 1.4059082786843646e-06, 1.349259370897471e-09, 1.6299211438308703e-06, 1.8368622595188455e-11, 7.87003671121056e-07, 4.697930044983423e-09, 7.772875392220158e-07, 8.645525961803457e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.9779369114791834e-12, 2.0301723843707542e-11, 9.640063858284975e-09, 5.633154955830832e-07, 1.0855606547011121e-07, 5.9819198483523905e-09, 6.220061266049015e-08, 9.076774887262218e-08, 1.0597575039739127e-09, 3.0598332756426316e-08, 2.1591845325019676e-06, 1.9815792062782833e-10, 6.076341652061501e-09, 1.6684102988051563e-08, 1.4792740365976442e-09, 0.9999964237213135, 1.8821591396545045e-08, 8.887510172250757e-11, 4.904191541754699e-07, 2.3847158622802844e-11, 1.2992775744180562e-08, 1.8430020010118398e-10, 3.899511469285244e-08, 1.1427755269854956e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.29536814397602e-09, 1.8992099004577767e-09, 1.311119945057726e-06, 9.506309288553894e-05, 1.1437209650466684e-06, 0.0023212372325360775, 0.0002587942290119827, 0.32151320576667786, 2.1188625396462157e-06, 5.536440994546865e-07, 0.0003688767028506845, 1.6769072885836067e-07, 5.944942245150742e-07, 2.3423492621077457e-06, 4.2869990579674777e-07, 0.6747556328773499, 0.0005550681962631643, 6.006372643696523e-08, 2.518661494832486e-05, 1.3007883659099662e-09, 7.988404831849039e-05, 3.4188684594482766e-07, 1.7949185348697938e-05, 7.913827815286822e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.6907550663344817e-12, 1.8196546699988936e-11, 9.31350996324909e-09, 5.657901169797697e-07, 1.0648932402546052e-07, 4.329837821615001e-09, 4.812831022604769e-08, 8.133981310720628e-08, 9.008400136956141e-10, 2.7494749588186096e-08, 1.9588599116104888e-06, 1.5780972362211543e-10, 6.246012151933655e-09, 1.4804041548188707e-08, 1.4428753747353085e-09, 0.9999966621398926, 1.3904431384048621e-08, 8.28589002965785e-11, 4.050265545174625e-07, 2.0804427625087385e-11, 1.0475795342301808e-08, 1.6378565170782622e-10, 3.063179931928062e-08, 9.910558484982346e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.2961889334371932e-11, 9.009795687298094e-11, 9.957022228945789e-08, 1.807648004614748e-05, 6.786813742110098e-07, 4.4548144728651096e-08, 2.034497157410442e-07, 1.1665978490782436e-05, 1.761666257316108e-09, 1.8371265753103216e-07, 1.6241656339843757e-06, 1.0490661672690749e-08, 6.099203631038108e-08, 9.498240615357645e-06, 2.730718984267355e-09, 0.9999575614929199, 2.7979581318504643e-08, 1.5586969492886737e-09, 1.4264925596307876e-07, 2.608452343011436e-11, 2.6555998289268246e-08, 2.0439816506012676e-09, 2.7682000691697795e-08, 2.1605132960456075e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.914104291733665e-12, 1.648121222830312e-11, 9.05603592116222e-09, 3.18984888281193e-07, 1.3849565050350066e-07, 3.005420357027333e-09, 4.4353761552429205e-08, 4.2647357645364536e-08, 1.2417616934712328e-09, 3.151740202156361e-08, 9.334643777947349e-07, 1.5017889709589838e-10, 9.227043129556023e-09, 7.980635707838246e-09, 1.1192905491341776e-09, 0.9999982118606567, 6.055399737192602e-09, 1.6583417972171333e-10, 2.886970662530075e-07, 2.4249968352818563e-11, 4.100516814986577e-09, 1.3705589441137533e-10, 1.5142592957317902e-08, 1.223335044375773e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.7331834752110087e-12, 1.261273203934099e-11, 1.8309664895355127e-08, 1.2785559420080972e-06, 7.215719932673892e-08, 5.917241807651408e-09, 1.6002972813566885e-07, 7.087194262567209e-07, 1.543510652624036e-09, 2.9788870037350534e-08, 2.7121018320031e-07, 1.394647036745411e-10, 3.6482339371701755e-09, 9.918824872556797e-08, 9.75483582799086e-10, 0.9999972581863403, 5.842283989920816e-09, 8.505897375332694e-11, 7.231344056890521e-08, 5.598371592696605e-12, 7.870609053384214e-09, 5.421477711209377e-10, 1.385926839958529e-08, 7.377785188333874e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.7331834752110087e-12, 1.261273203934099e-11, 1.8309664895355127e-08, 1.2785559420080972e-06, 7.215719932673892e-08, 5.917241807651408e-09, 1.6002972813566885e-07, 7.087194262567209e-07, 1.543510652624036e-09, 2.9788870037350534e-08, 2.7121018320031e-07, 1.394647036745411e-10, 3.6482339371701755e-09, 9.918824872556797e-08, 9.75483582799086e-10, 0.9999972581863403, 5.842283989920816e-09, 8.505897375332694e-11, 7.231344056890521e-08, 5.598371592696605e-12, 7.870609053384214e-09, 5.421477711209377e-10, 1.385926839958529e-08, 7.377785188333874e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.571202612460354e-09, 1.1423931800536025e-09, 2.0883572915408877e-07, 0.00028288864996284246, 6.909193075443909e-07, 3.7194466131040826e-05, 0.00014796113828197122, 0.003290969878435135, 3.9963128983799834e-07, 3.78857265559418e-07, 3.7442347093019634e-05, 4.17689349774264e-08, 3.142293110158789e-07, 8.232887012127321e-06, 6.398077800895408e-08, 0.9961647987365723, 2.5731305868248455e-06, 1.2488793998954861e-08, 1.0640997061273083e-05, 2.0735038686048313e-10, 1.218802026414778e-05, 7.439147964305448e-08, 2.888725475713727e-06, 8.572681231555634e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.172784618892365e-09, 1.4305404638648156e-09, 1.8663158130038937e-07, 0.0005047191516496241, 5.145918180460285e-07, 4.214508589939214e-05, 0.0002332404546905309, 0.006940685678273439, 4.0139983070730523e-07, 3.808246162861906e-07, 0.0001975399354705587, 5.0823320663084814e-08, 2.204727280741281e-07, 3.5908044537791284e-06, 4.144424536889346e-08, 0.9920513033866882, 3.700103434312041e-06, 1.2521842229773483e-08, 9.072237844520714e-06, 1.6709400529890672e-10, 8.766504834056832e-06, 4.556407162681353e-08, 3.530720732669579e-06, 9.768551301192474e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.99488124872005e-12, 3.119620187175265e-11, 1.2038840146999519e-08, 2.1786991055705585e-06, 1.1440883440627658e-07, 7.279217228983725e-09, 1.0725496935037881e-07, 2.557171683292836e-07, 2.619271466386408e-09, 2.770389784245708e-08, 1.7722802567732288e-06, 1.6838153094056452e-10, 1.2743761601541337e-08, 4.179156221084668e-08, 1.80214854150762e-09, 0.9999948740005493, 1.2687688233370409e-08, 1.3686447808414215e-10, 5.166850201021589e-07, 2.080217074984514e-11, 1.6078098852290168e-08, 3.3486854955633305e-10, 3.6285115356804454e-08, 1.5387500995611703e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.6303508543202838e-09, 1.2115484171459912e-09, 3.0505884751619305e-07, 4.083497333340347e-05, 1.3268261227494804e-06, 8.663457265356556e-05, 3.50671834894456e-05, 0.1263933628797531, 8.141786338455859e-07, 6.922006150489324e-07, 0.0029606837779283524, 2.064538904278379e-07, 4.637134622953454e-07, 8.407310474467522e-07, 1.955400676934005e-07, 0.8702493906021118, 4.539216388366185e-05, 2.0942714229477133e-08, 8.975533091870602e-06, 3.8836878157866295e-10, 0.0001677668624324724, 6.488867398957154e-08, 6.980905254749814e-06, 4.557560107087966e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.7777996876597886e-12, 2.9696453629490804e-11, 1.1016863865620508e-08, 1.9284707377664745e-06, 1.0932429006516031e-07, 7.47326023287087e-09, 1.1190766002755481e-07, 2.760295672032953e-07, 2.7743964903237384e-09, 2.7908189537129147e-08, 2.0368379409774207e-06, 1.5573992095951894e-10, 1.1897901330826244e-08, 3.8256946055525987e-08, 1.7031964727465265e-09, 0.9999948740005493, 1.2253358327996011e-08, 1.1873722838284806e-10, 5.363792183743499e-07, 2.098900914182522e-11, 1.7934910445660535e-08, 3.0835595188349885e-10, 3.7608838709957126e-08, 1.4985249152665858e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.23023178985904e-11, 1.4864763586697194e-10, 8.549995555995338e-08, 2.6934267225442454e-05, 5.594642402684258e-07, 2.4695347633496567e-07, 6.712853632961924e-07, 4.923285814584233e-05, 5.888940002307663e-09, 2.311406746002831e-07, 1.6645915820845403e-05, 2.0661095945229135e-08, 5.999207530749118e-08, 5.417403826868394e-06, 4.916115514674857e-09, 0.9998986721038818, 2.1426941998470284e-07, 1.172433372609305e-09, 4.7085558207982103e-07, 4.6328690883612467e-11, 2.913341177190887e-07, 4.1758516644563315e-09, 1.864072629587099e-07, 4.973759182291815e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.019249351059571e-12, 1.9820688493266125e-11, 7.324097772709592e-09, 4.1867227196235035e-07, 1.3181346503188252e-07, 4.002870035435535e-09, 6.297845800418145e-08, 8.042356114401628e-08, 1.6436144667508756e-09, 3.067809117851539e-08, 2.755106379481731e-06, 1.5654243179508143e-10, 8.349925195716423e-09, 1.405311778057694e-08, 1.1040431902031855e-09, 0.9999960660934448, 1.2633755375190958e-08, 9.019014701738826e-11, 3.7155612631067925e-07, 2.6081697565571993e-11, 1.0688866680652609e-08, 1.6123921642297034e-10, 2.9533460121911048e-08, 1.248784270435621e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.225513393364076e-12, 1.675653539534583e-11, 1.3136330245799854e-08, 7.553408067906275e-07, 1.1806753974497042e-07, 5.906716893377961e-09, 1.3332441994862165e-07, 2.92681846758569e-07, 1.4773651191291037e-09, 3.8711952754511e-08, 2.13133333204496e-07, 2.2406017319287486e-10, 6.83963730097048e-09, 8.840523690878399e-08, 7.733280127375508e-10, 0.9999983310699463, 7.265385626453735e-09, 8.036796228516607e-11, 9.847241955185382e-08, 7.978220514792689e-12, 7.720623251827874e-09, 4.6247333740367935e-10, 1.4114530877407105e-08, 1.390372400544848e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.225513393364076e-12, 1.675653539534583e-11, 1.3136330245799854e-08, 7.553408067906275e-07, 1.1806753974497042e-07, 5.906716893377961e-09, 1.3332441994862165e-07, 2.92681846758569e-07, 1.4773651191291037e-09, 3.8711952754511e-08, 2.13133333204496e-07, 2.2406017319287486e-10, 6.83963730097048e-09, 8.840523690878399e-08, 7.733280127375508e-10, 0.9999983310699463, 7.265385626453735e-09, 8.036796228516607e-11, 9.847241955185382e-08, 7.978220514792689e-12, 7.720623251827874e-09, 4.6247333740367935e-10, 1.4114530877407105e-08, 1.390372400544848e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.3869454196235864e-10, 2.4047050461994957e-10, 5.1820119750800586e-08, 0.00011871018796227872, 2.277529631555808e-07, 1.0741551932369475e-06, 2.543745176808443e-05, 5.053908535046503e-05, 4.821430721335673e-08, 1.0410170148134057e-07, 7.873446520534344e-06, 6.808245522904599e-09, 3.815877747115337e-08, 1.214255576087453e-06, 1.3147237076793772e-08, 0.9997888207435608, 5.101260853734857e-07, 3.4749112476362143e-09, 3.971962996729417e-06, 3.3872651211686033e-11, 7.835577662262949e-07, 1.01190380519256e-08, 6.640950118708133e-07, 2.0939245892748204e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.238232251789874e-11, 4.8464704471840037e-11, 4.095046080010434e-08, 5.108525510877371e-05, 8.830693332129158e-08, 6.321857881630422e-07, 2.0747351300087757e-05, 6.468709761975333e-05, 9.983114068745635e-08, 2.018271239023761e-08, 2.7833502826979384e-06, 9.317583371526439e-10, 6.77726141873336e-09, 2.3037392793412437e-07, 1.014202144489218e-08, 0.9998546838760376, 2.2404458377422998e-07, 7.508439980874471e-10, 1.7825420854933327e-06, 9.47850478660861e-12, 1.8375394574832171e-06, 8.88253204323064e-09, 9.745277793626883e-07, 8.316096145044582e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.787667561724271e-12, 1.79186405296905e-11, 9.237559162045272e-09, 6.267451340136176e-07, 1.0815060846880442e-07, 4.397854969084847e-09, 6.521031536976807e-08, 1.1113148445929255e-07, 1.2206068378262103e-09, 2.302799906317432e-08, 1.9883284494426334e-06, 1.4960258032381546e-10, 5.476258113645827e-09, 1.8662804635027896e-08, 1.5686719700980234e-09, 0.9999966621398926, 1.262376780886143e-08, 8.694658881758244e-11, 4.111000748707738e-07, 1.812999576855656e-11, 1.3857516023563221e-08, 2.010851068989794e-10, 3.3296327472953635e-08, 1.0878268424940885e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.003172155402467e-09, 8.129125150801997e-10, 3.134372548174724e-07, 3.599218325689435e-05, 4.0173281945499184e-07, 0.002048182999715209, 0.0003311029577162117, 0.04835767671465874, 3.7664683532057097e-06, 1.638832145545166e-07, 0.00016506316023878753, 1.0182205301134672e-07, 1.9308984633426007e-07, 4.4353330963531334e-07, 3.8976065752649447e-07, 0.9474325776100159, 0.00026412485749460757, 2.4111303176255205e-08, 1.3411140571406577e-05, 2.491901407442043e-10, 0.0013025440275669098, 3.7305107980500907e-07, 4.2997620766982436e-05, 4.212633797351373e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.0086864029739138e-12, 1.8962597117533342e-11, 9.285145985415966e-09, 6.520685360555944e-07, 1.0679848116978974e-07, 5.33852340112162e-09, 7.267911428243679e-08, 1.3340303439690615e-07, 1.3622876160468422e-09, 2.5073624954075058e-08, 2.1344362721720245e-06, 1.7481738279201409e-10, 6.071394498263771e-09, 2.396346410193928e-08, 1.5239099981911863e-09, 0.9999964237213135, 1.509953584388768e-08, 9.113781257452658e-11, 4.343886814694997e-07, 1.9404656700916512e-11, 1.567341456620852e-08, 2.2558849233078604e-10, 3.8594361484456385e-08, 1.169349200802472e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[7.223572850989513e-08, 3.932920833449316e-08, 2.894433464462054e-06, 8.197919669328257e-06, 2.09003974305233e-06, 0.001356271794065833, 4.987565625924617e-05, 0.08644130080938339, 1.9616038116510026e-05, 5.641950338031165e-06, 0.03015155717730522, 8.546706453671504e-07, 1.9738728951779194e-05, 6.394225238182116e-07, 4.4650150812231004e-06, 0.8795844316482544, 0.00011446108692325652, 6.908088323598349e-08, 0.0003680219524540007, 4.941932161273144e-07, 0.0018152721459046006, 2.720213956308726e-07, 5.377919660531916e-05, 2.963587064641615e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.8995998190869425e-12, 3.252730376712698e-11, 1.4566595041287655e-08, 7.897117484390037e-07, 1.1629556695424981e-07, 1.7273794838956746e-08, 1.1919555475969901e-07, 5.775208364866558e-07, 7.936142409903368e-09, 3.449802576938055e-08, 4.8767406042316e-06, 1.6074695741163936e-10, 2.622354777770397e-08, 1.9886758906295654e-08, 1.776479408022169e-09, 0.9999921321868896, 1.7064280655176844e-08, 1.6954315729122982e-10, 1.084894165614969e-06, 4.500946143570772e-11, 4.5923620461962855e-08, 4.759592164838011e-10, 5.584724149798603e-08, 1.5969539579607783e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.7670587832726596e-07, 2.3482830613374972e-07, 3.7117413285159273e-06, 3.539112731232308e-05, 5.762712135037873e-06, 0.008292384445667267, 0.0004490537103265524, 0.03827598690986633, 1.4129898772807792e-05, 5.895301728742197e-05, 0.1714150756597519, 7.629029278177768e-05, 5.211643292568624e-05, 3.8579199213018e-07, 1.0000087058870122e-05, 0.7713542580604553, 0.0018964374903589487, 1.341000029242423e-06, 0.000871613621711731, 5.039383950133924e-07, 0.006961692590266466, 5.993063609821547e-07, 0.0002233999693999067, 1.750194229543922e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.672681082866891e-12, 3.1652177406860105e-11, 7.767534171421175e-09, 7.108482122930582e-07, 1.3646162244640436e-07, 4.718900825650962e-09, 5.3152884760265806e-08, 1.394365654050489e-07, 2.562848600007328e-09, 4.4937142007484e-08, 7.285939773282735e-06, 1.9470208778571418e-10, 1.9810666884723105e-08, 1.428591822616454e-08, 1.7267467455894803e-09, 0.9999904632568359, 1.6214857012641914e-08, 1.3150579236675952e-10, 9.534760465612635e-07, 3.722850153153878e-11, 2.156642153749999e-08, 1.7023372989033447e-10, 3.863832276351786e-08, 1.3365569762058271e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.212229536866175e-10, 1.4014946980722698e-09, 3.047290135782532e-07, 0.00010763669706648216, 1.514711925665324e-06, 2.6982579584000632e-06, 3.0164319468894973e-06, 0.00011495726357679814, 3.084867827851667e-08, 9.051229312717624e-07, 6.293772912613349e-06, 1.3011235466819926e-07, 3.3480321803835977e-07, 9.397542271472048e-06, 1.241892899628283e-08, 0.999750554561615, 2.3718020258911565e-07, 3.0667049344401676e-08, 1.0062385626952164e-06, 2.021726536183266e-10, 5.754760081799759e-07, 1.9372405901663114e-08, 2.397456455582869e-07, 2.2669630617144776e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.681959351806765e-13, 9.043367617256326e-12, 1.3260459397201885e-08, 7.445260052918456e-08, 6.637834815137467e-08, 2.024570955327931e-09, 1.5606470782358883e-08, 2.0853804016951472e-07, 1.6243946188154723e-09, 1.7977539457092462e-08, 5.028629402659135e-06, 3.277754803687749e-11, 4.71944039404093e-09, 2.187451109136873e-09, 1.0870800926099378e-09, 0.9999942779541016, 6.670067165259752e-09, 3.709290860576253e-11, 1.9433990416928282e-07, 1.8294990522527144e-11, 1.706662899891853e-08, 1.0692384477817285e-10, 1.9940545215035854e-08, 5.121355770021374e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[9.860851832854678e-07, 1.6198822549995384e-07, 4.403827915666625e-06, 2.8496975573943928e-05, 3.877819835906848e-06, 0.1213456392288208, 0.0010326829506084323, 0.40989068150520325, 5.1004513807129115e-05, 1.7724709323374555e-05, 0.021727263927459717, 3.65351588698104e-05, 2.5465644284849986e-05, 1.50378895114045e-07, 1.1485535651445389e-05, 0.4248196482658386, 0.002048105001449585, 9.296086886934063e-07, 0.00040723258280195296, 3.7269424524311034e-07, 0.018251923844218254, 2.067070226985379e-06, 0.0002928636968135834, 2.2856248449443228e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.7894414209028717e-12, 1.8668374138219868e-11, 1.1647990127983121e-08, 4.1877694911818253e-07, 8.154598418741443e-08, 1.175547836851365e-08, 6.923912820866462e-08, 5.353123810891702e-07, 5.710496520094921e-09, 2.614561900315948e-08, 6.406816737580812e-06, 9.696378422408003e-11, 1.236445790198104e-08, 7.603295770763907e-09, 1.650102610106785e-09, 0.9999914169311523, 1.7494510728965906e-08, 9.771272679870435e-11, 9.015267892209522e-07, 3.0544313606162277e-11, 5.228517707678293e-08, 3.4183439412416305e-10, 5.373139799758064e-08, 1.0409523243382068e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.82740061602938e-11, 2.5999469244197826e-10, 1.2189907749871054e-07, 3.227413253625855e-05, 1.070734811037255e-06, 1.5715241374891775e-07, 4.517470699738624e-07, 2.6007915948866867e-05, 3.2913096692510635e-09, 4.841465965910174e-07, 1.150858497567242e-05, 6.201616287171419e-08, 1.137588370170306e-07, 4.057194473716663e-06, 1.0965080399216731e-08, 0.9999220371246338, 2.1352128953822103e-07, 1.6372228017758061e-09, 8.026724458432e-07, 4.929784705454132e-11, 6.204731448633538e-07, 3.2410985006947612e-09, 1.1106894248769095e-07, 5.214476628268017e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.403049768380904e-12, 2.1819294634961572e-11, 9.33269994618513e-09, 3.233801635360578e-07, 1.052378877375304e-07, 3.024831940479089e-09, 2.4262652331685786e-08, 1.214808946770063e-07, 1.2096793566840347e-09, 4.293820055067954e-08, 1.700742905086372e-05, 1.4866793907053477e-10, 7.059824280730709e-09, 4.063398062470469e-09, 1.6315471196293174e-09, 0.9999817609786987, 1.8694946035680005e-08, 1.0070740075196483e-10, 5.077499736216851e-07, 2.774632433533153e-11, 2.1480394352124677e-08, 9.12571962441433e-11, 3.590016817156538e-08, 1.0703861408334348e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.1613196799517027e-07, 1.1756878137703097e-07, 2.7208548090129625e-06, 0.0001868680992629379, 5.933130523771979e-06, 0.019354669377207756, 0.00034070550464093685, 0.1944592446088791, 6.430575012927875e-06, 9.797899110708386e-05, 0.07179633527994156, 0.000520634523127228, 2.4589868189650588e-05, 4.897078156318457e-07, 6.719669272570172e-06, 0.7067575454711914, 0.0022963883820921183, 1.8099650560543523e-06, 0.00022618028742726892, 1.224347840889095e-07, 0.0036707590334117413, 8.423486974606931e-07, 0.00024227310495916754, 1.5880104342613777e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.8051485653480803e-11, 6.373617605914816e-11, 1.6433613581057216e-08, 3.8068938010837883e-06, 1.1620178952398419e-07, 6.874925873034954e-08, 4.206272876672301e-07, 2.313918002982973e-06, 1.298754259693169e-08, 5.892775334359612e-08, 2.3009601136436686e-05, 7.5544820399287e-10, 3.001279580416849e-08, 5.2636437430919614e-08, 4.791484098376486e-09, 0.9999655485153198, 9.551499857707313e-08, 4.346166204705071e-10, 3.872350134770386e-06, 5.2996596694443454e-11, 2.6883611781158834e-07, 1.0254175286661393e-09, 2.3016360728433938e-07, 3.7596795121608295e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.7130298835563735e-10, 3.3618663408674365e-10, 1.7355212378333817e-07, 2.1696272597182542e-05, 6.447278337873286e-07, 3.470134106464684e-05, 9.501804015599191e-06, 0.004285607952624559, 1.791020736163773e-07, 5.043033866058977e-07, 2.9816506867064163e-05, 1.74093450766577e-08, 3.256685658925562e-07, 2.937696990557015e-06, 1.859230458478578e-08, 0.9955978989601135, 1.724408889458573e-06, 4.19303569643148e-09, 1.7910592760017607e-06, 2.1596117949496119e-10, 1.1314047696941998e-05, 4.1131766437274564e-08, 1.1163582485096413e-06, 1.6501701116666823e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.6143862186245315e-08, 1.1930124443892964e-08, 3.624871283136599e-07, 0.00013174375635571778, 2.2923989035916748e-06, 0.00016017815505620092, 0.0004807758377864957, 0.0008114702068269253, 8.590758397986065e-07, 3.881751126755262e-06, 0.0007012837450020015, 3.818735876848223e-06, 9.286934073315933e-06, 1.4387369446922094e-05, 5.60238845537242e-07, 0.9969363212585449, 3.1216175557347015e-05, 1.9951257002048806e-07, 0.0005200582672841847, 8.027950748612511e-09, 0.00015688734129071236, 2.744480696037499e-07, 3.403803566470742e-05, 2.7486310116842105e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.956100955321897e-13, 9.777251057385694e-12, 1.3283734112690126e-08, 7.628792531022555e-08, 7.495320630823699e-08, 1.9993107169824498e-09, 1.4407480541933637e-08, 1.569377303667352e-07, 1.703278185161139e-09, 1.901987012331574e-08, 6.179770480230218e-06, 3.481151478190725e-11, 3.985929808436595e-09, 1.600731880380124e-09, 1.1959214729628798e-09, 0.9999932050704956, 7.862640316602665e-09, 3.465371392619154e-11, 2.232130924539888e-07, 2.0143862272670177e-11, 1.877996780308422e-08, 1.016022474487066e-10, 2.2080527628531854e-08, 5.48358129737192e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.3188532297508937e-12, 1.8359853568017392e-11, 9.014218704805899e-09, 3.614833872234158e-07, 8.980209997844213e-08, 2.6925641716246673e-09, 2.347476346642452e-08, 1.222127536948392e-07, 9.093997777043228e-10, 3.7718400847097655e-08, 1.3161364222469274e-05, 1.3587328484554462e-10, 6.597106416705856e-09, 5.06520558829493e-09, 1.448661413050445e-09, 0.9999856948852539, 1.567578777894596e-08, 9.451495835977042e-11, 4.403140962949692e-07, 2.500645523983991e-11, 1.6798654911553967e-08, 7.92330298593491e-11, 3.082875821291964e-08, 9.572689169123905e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.8144052232882402e-11, 8.387932709519319e-11, 5.9415828701503415e-08, 2.453706292726565e-05, 4.7445644213439664e-07, 5.8549257886397754e-08, 2.338085067776774e-07, 9.68618223851081e-06, 2.452819281018037e-09, 1.162723251013631e-07, 1.6483280660395394e-06, 3.6807696890406305e-09, 4.989658108911499e-08, 5.566350409935694e-06, 3.161230166526252e-09, 0.9999572038650513, 4.5948649329830005e-08, 6.021954601642676e-10, 2.4927933850449335e-07, 2.3817902511380495e-11, 5.1261963562865276e-08, 2.1802764038625355e-09, 5.405427572213739e-08, 2.1992832555106645e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.994496891058299e-13, 8.171785297050871e-12, 1.0403060635155725e-08, 8.445157106962142e-08, 1.0699650943024608e-07, 1.6002982272667055e-09, 1.5198823533069117e-08, 2.3958630634979272e-08, 3.219140787269481e-10, 2.3659367798245512e-08, 7.620012070219673e-07, 8.821732927488668e-11, 2.7905411315032325e-09, 2.426675527189559e-09, 1.0061700361774228e-09, 0.9999988079071045, 8.575722354464688e-09, 4.5739405318823145e-11, 1.590202742818292e-07, 1.4229450083502737e-11, 3.138477255859584e-09, 6.843091371333543e-11, 1.0815284667842207e-08, 4.7986996321025543e-11]]
# Predicted class: 7
# predicted class is :  DoS SlowHTTPTest
# Class probabilities: [[1.0374314740602131e-07, 2.605694326973662e-08, 1.8545019884186331e-06, 0.00011262796761002392, 1.2418063306540716e-05, 0.01864214986562729, 0.0009249693248420954, 0.6526842713356018, 5.219922513788333e-06, 1.8516788259148598e-05, 0.005699272267520428, 8.438342047156766e-05, 5.881674496777123e-06, 1.9039812286791857e-06, 8.385087312490214e-06, 0.3118944764137268, 0.008986026048660278, 6.050698857507086e-07, 0.00017152729560621083, 7.974527704845968e-08, 0.0005186384078115225, 1.6562187283852836e-06, 0.00022489823459181935, 1.0070599643086098e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.7904701159199288e-12, 1.914764354016274e-11, 9.184700999753659e-09, 4.3671141725099005e-07, 1.0369867453619008e-07, 6.084824200058847e-09, 6.408118480294434e-08, 1.222914676191067e-07, 1.0727393418008546e-09, 3.246770674536492e-08, 3.3537210128997685e-06, 1.8426871140064804e-10, 5.829472016216641e-09, 1.522976411649779e-08, 1.4071285248107301e-09, 0.9999953508377075, 1.9605149503831854e-08, 7.699989257314854e-11, 4.838644827032113e-07, 2.6769128580461654e-11, 1.3533727027947862e-08, 1.6841886218976754e-10, 4.266049558054874e-08, 1.1042734782140684e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.0478369827946494e-10, 6.933348339899226e-10, 2.1179943132665358e-07, 0.00019887505914084613, 1.4238273706723703e-06, 1.5907257875369396e-06, 2.5337192255392438e-06, 0.0005142200388945639, 2.5534136582905376e-08, 5.260887405711401e-07, 1.8394664948573336e-05, 8.392658656930507e-08, 2.0871870276550908e-07, 2.49534314207267e-05, 1.979442565414047e-08, 0.999233603477478, 3.9474397794947436e-07, 5.747205378270337e-09, 1.3331493846635567e-06, 9.889349061875663e-11, 1.3000321814615745e-06, 1.7516098793635138e-08, 4.080326050370786e-07, 1.774800084675121e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.0416421414652377e-12, 1.7860123102675374e-11, 1.3855482983160528e-08, 3.4536355997261126e-07, 8.829067610349739e-08, 2.456296499531163e-09, 2.32368719821352e-08, 2.033820436508904e-07, 1.0950741424764487e-09, 3.250102409424471e-08, 9.884995051834267e-06, 9.115522919822538e-11, 4.823231591899457e-09, 3.4394491699174523e-09, 1.0516271187199777e-09, 0.9999891519546509, 1.241125957562872e-08, 1.0884952661438518e-10, 1.8504128718177526e-07, 1.5633359190525553e-11, 7.189706607846347e-09, 6.409340419510912e-11, 1.473952249142485e-08, 6.598305929417236e-11]]
# Predicted class: 7
# predicted class is :  DoS SlowHTTPTest
# Class probabilities: [[2.3339912047504185e-07, 6.767492521930762e-08, 2.820588633767329e-06, 5.568308915826492e-05, 9.695889275462832e-06, 0.005839123390614986, 3.848941560136154e-05, 0.5311874151229858, 2.377202008574386e-06, 4.823724157176912e-05, 0.0865827277302742, 9.094050619751215e-05, 3.655451655504294e-05, 4.6265765263342473e-07, 2.4286628104164265e-06, 0.3753521740436554, 0.00048448785673826933, 4.579998744702607e-07, 6.394639058271423e-05, 1.3788051944629842e-07, 0.00018887965416070074, 1.9059547184951953e-07, 1.2407277608872391e-05, 3.249079227884977e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.055307738920488e-12, 3.1329598637608314e-11, 1.1560318036174522e-08, 1.8235529068988399e-06, 1.1737311922388471e-07, 8.799693418382049e-09, 1.2640255420137692e-07, 4.123763517327461e-07, 2.933797649262715e-09, 3.0950353391290264e-08, 3.6666269807028584e-06, 1.8411407121110557e-10, 1.2057891574102086e-08, 3.7755896187263716e-08, 1.9612462764939664e-09, 0.999993085861206, 1.578078290265239e-08, 1.3012459165739898e-10, 6.019860165906721e-07, 2.3909063964766553e-11, 2.328390102945832e-08, 3.057562536490366e-10, 4.5003645254837465e-08, 1.5986591217487245e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[7.742242957853307e-11, 2.594124359767136e-10, 1.7282135900131834e-07, 0.00011798804916907102, 1.0543549251451623e-06, 1.677116898690656e-07, 8.597814371569257e-07, 3.624383680289611e-05, 3.70846486852372e-09, 2.355385504415608e-07, 1.8503693581806147e-06, 2.5289256910809854e-08, 1.139837522146081e-07, 8.156706462614238e-05, 6.372003813481797e-09, 0.9997591376304626, 1.0369217307015788e-07, 1.985785758051861e-09, 2.8232781801307283e-07, 3.4970786683130584e-11, 1.2144539596192772e-07, 7.642540822416777e-09, 9.467824924058732e-08, 4.1445608056633887e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.396325205263286e-13, 8.605135701222899e-12, 1.229625024024017e-08, 8.436992970928259e-08, 1.0633954161676229e-07, 1.3947775157063802e-09, 1.9026071385042087e-08, 3.017336069888188e-08, 4.321124014161626e-10, 1.4948723148222598e-08, 8.435854965682665e-07, 9.050539484523057e-11, 1.950717809506841e-09, 3.1986140403006402e-09, 1.1802828714380098e-09, 0.9999986886978149, 1.1732201876668569e-08, 5.840715411320474e-11, 1.7375529637320142e-07, 1.0126611355021353e-11, 5.156207905088195e-09, 8.906383269779994e-11, 1.5435961842058532e-08, 4.42893811902767e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.3777109226539324e-07, 6.098871097037772e-08, 1.7998853536482784e-06, 0.0001541133678983897, 6.13307429375709e-06, 0.14692451059818268, 0.0015004304004833102, 0.22058771550655365, 9.502289685769938e-06, 1.2052353667968418e-05, 0.0020852910820394754, 0.00019899180915672332, 1.0223354365734849e-05, 2.1387972992670257e-06, 7.209620889625512e-06, 0.6230652332305908, 0.0027288475539535284, 1.1030215318896808e-06, 0.0006140770856291056, 8.561767117498675e-08, 0.001750711351633072, 3.1161932838585926e-06, 0.00033603687188588083, 1.287292548113328e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.7603793856652006e-12, 1.7016625955545983e-11, 9.44930533819388e-09, 6.508971637231298e-07, 1.0784352610926362e-07, 4.225217065112474e-09, 6.158090570806962e-08, 1.1276474509713807e-07, 1.2938123905570365e-09, 2.1211764789086374e-08, 1.6138676528498763e-06, 1.375103086953544e-10, 5.626854537865711e-09, 1.8478235830343692e-08, 1.566023755117385e-09, 0.9999970197677612, 1.1917346220968739e-08, 8.638970788732436e-11, 3.8478637520711345e-07, 1.6317072693006196e-11, 1.3372887686102786e-08, 2.209415567167028e-10, 3.1444713499695354e-08, 1.0648554260583865e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.789960012490212e-11, 1.7681221764487276e-10, 3.07224148343721e-08, 1.6829126252559945e-05, 2.048449090352733e-07, 1.6197614627344592e-07, 2.3821248760214075e-06, 8.627094757684972e-06, 1.8296688608643308e-08, 9.945598833382974e-08, 2.6977199013344944e-05, 2.6087443316669123e-09, 2.806601528959618e-08, 8.227693797380198e-07, 5.149981774366097e-09, 0.9999368190765381, 6.666651302111859e-07, 2.0759522989521884e-09, 5.63967523703468e-06, 4.279990598043959e-11, 2.9854570016141224e-07, 3.551537508528213e-09, 4.906682988803368e-07, 1.0634239044904348e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.8415293734364013e-09, 2.262516174411644e-09, 2.1341203648717055e-07, 0.00016335373220499605, 1.3006466588194598e-06, 3.1347168260253966e-05, 7.334742258535698e-05, 0.0025044563226401806, 4.3595591137091105e-07, 6.043632652108499e-07, 0.0006565055809915066, 1.1362474339193795e-07, 4.1654183746686613e-07, 6.116078111517709e-06, 1.0697720398411548e-07, 0.9964790940284729, 1.1499592801555991e-05, 2.3496141920986702e-08, 4.244063893565908e-05, 5.486150422839842e-10, 2.275714541610796e-05, 6.516948047874394e-08, 5.8983341659768485e-06, 8.769591275381572e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[9.17302969694056e-11, 3.292389971765175e-10, 3.369287426835399e-08, 2.835505802067928e-05, 2.553830711349292e-07, 3.233891447962378e-07, 3.3818230349424994e-06, 7.933892447908875e-06, 2.8529505868846172e-08, 1.4261081560107414e-07, 4.2601761379046366e-05, 5.6696451977700235e-09, 3.644339940933605e-08, 1.086387214854767e-06, 8.021785902201373e-09, 0.9999016523361206, 1.0373036047894857e-06, 3.645012514041923e-09, 1.1752289537980687e-05, 6.110764672051516e-11, 6.490549253612699e-07, 5.0959916286785756e-09, 6.436502530959842e-07, 1.9442327747754007e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.44265479039685e-13, 7.793778643294669e-12, 9.457651550803803e-09, 7.493446929629499e-08, 1.0810855144427478e-07, 1.4660085367879105e-09, 1.2641115709755013e-08, 1.9706888565451663e-08, 2.9664540268647954e-10, 2.3578143881763935e-08, 8.174891377166205e-07, 9.389287958239123e-11, 2.4455402147793848e-09, 2.091055328889979e-09, 1.0451423060331422e-09, 0.9999986886978149, 9.922314525567799e-09, 4.350222959637051e-11, 1.5722862656275538e-07, 1.4380302504335418e-11, 3.0910158876906735e-09, 6.205028851846706e-11, 1.1254398302185109e-08, 4.555899754676851e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[9.794163093393427e-13, 1.3254313445398846e-11, 1.970363605607872e-08, 2.736157114213711e-07, 8.670187412462838e-08, 2.3760176048881476e-09, 2.41003608181245e-08, 2.91133261498544e-07, 7.36960548142207e-10, 3.384954894158909e-08, 9.184665941575076e-06, 9.886080842846923e-11, 5.365264232892741e-09, 6.406895902699716e-09, 1.0642028369645118e-09, 0.9999899864196777, 1.110713565566357e-08, 9.650423515861206e-11, 1.466872703304034e-07, 1.8209793048451495e-11, 6.064133639682723e-09, 6.427108151241256e-11, 1.26071526551641e-08, 5.392127022663118e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.912770815498514e-13, 9.971437738010014e-12, 1.0351992152379808e-08, 7.769987320216387e-08, 1.209001112556507e-07, 1.4329254449663154e-09, 1.7060811430269496e-08, 2.3528771819769645e-08, 4.556388322196625e-10, 1.753783607227888e-08, 8.478277777612675e-07, 1.0980602538346318e-10, 2.312852576125124e-09, 2.5011048787604295e-09, 1.2720684505751478e-09, 0.9999986886978149, 1.1458720194923444e-08, 6.048493650379072e-11, 1.964349678473809e-07, 1.2053709592951822e-11, 4.780834395035072e-09, 8.617048047332432e-11, 1.565964424798949e-08, 4.995856853207137e-11]]
# Predicted class: 10
# predicted class is :  FTP Patator
# Class probabilities: [[1.3298276257955877e-08, 1.244102243447287e-08, 6.9989101803003e-07, 3.822831786237657e-05, 1.2795311704394408e-05, 0.00028118942282162607, 1.267705829377519e-05, 0.18284428119659424, 7.393838359348592e-07, 6.985254003666341e-05, 0.45528194308280945, 5.3260137065080926e-05, 3.0197757041605655e-06, 2.2321485459997348e-07, 2.0869435957138194e-06, 0.36066240072250366, 0.0006151234265416861, 8.607266721583073e-08, 1.5459179849131033e-05, 5.60860051734835e-08, 7.972937601152807e-05, 4.360470029496355e-08, 2.609138573461678e-05, 1.4221406274828041e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.565309919661424e-12, 6.192991258702207e-11, 1.706764329867383e-08, 3.2837967864907114e-06, 1.4233179967959586e-07, 1.6666644953033938e-08, 1.7946172192750964e-07, 1.0201815712207463e-06, 4.33315872072626e-09, 5.624386645308732e-08, 1.7870788724394515e-05, 5.178853457188382e-10, 2.3339117305454238e-08, 1.3011892008307768e-07, 2.486155503689247e-09, 0.9999755620956421, 4.2976033398645086e-08, 2.9009375457356157e-10, 1.3788280739390757e-06, 4.897919222979219e-11, 4.1120802762861786e-08, 4.2144920886499904e-10, 9.367690978479004e-08, 2.412993416189835e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.260563984421651e-09, 3.0578497511868363e-09, 9.23929860618955e-07, 3.1443738407688215e-05, 3.088398671025061e-06, 6.955769640626386e-05, 8.614942998974584e-06, 0.06486514955759048, 3.4316488495278463e-07, 7.1968943302636035e-06, 0.10150064527988434, 5.498529390024487e-06, 3.5851990105584264e-06, 1.4303228681455948e-06, 8.114648153423332e-07, 0.8333848118782043, 6.913892866577953e-05, 3.272577231427931e-08, 2.278251304232981e-05, 4.66655443176478e-08, 1.5307319699786603e-05, 3.6554435922653283e-08, 9.513300028629601e-06, 5.705770078634487e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.475628300107168e-11, 5.890350013304513e-11, 2.7131578761441233e-08, 6.28834595772787e-06, 1.3791186859180016e-07, 5.7404481168532584e-08, 4.928340331389336e-07, 8.58419753058115e-06, 7.268515123115549e-09, 5.998990815214711e-08, 2.2424386770580895e-05, 7.264824852803997e-10, 4.0481644703049824e-08, 4.3262568283353176e-07, 2.9835729442595493e-09, 0.9999598264694214, 5.79295722502593e-08, 4.789937335658578e-10, 1.3257385944598354e-06, 6.14385625707925e-11, 7.203308172165634e-08, 1.3267736909128303e-09, 1.3877512117232982e-07, 2.999799852965168e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[1.7996551093801827e-07, 4.9826518022655364e-08, 9.073045248442213e-07, 0.00023295031860470772, 6.2348285609914456e-06, 0.0049600666388869286, 5.736876846640371e-05, 0.3606279492378235, 1.6262908957287436e-06, 6.141905760159716e-05, 0.15508237481117249, 7.721387373749167e-05, 5.128209522808902e-06, 2.5429764605178207e-07, 1.6778413964857464e-06, 0.4784005880355835, 0.000213409133721143, 2.6971332545144833e-07, 1.3380114069150295e-05, 2.9065434503650067e-08, 0.00023267035430762917, 1.6183176398953947e-07, 2.401326855760999e-05, 6.756472714641859e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.574278440032224e-12, 5.662360164082614e-11, 1.4059175157399295e-08, 3.838544671452837e-06, 1.0451006460243661e-07, 1.872090393817416e-08, 2.1116365189755015e-07, 7.737020837339514e-07, 3.669738068978745e-09, 4.3760568502193564e-08, 9.09495065570809e-06, 3.718713392775186e-10, 1.657422643575046e-08, 1.2185020636934496e-07, 2.591406644825156e-09, 0.9999845027923584, 2.6998133506594968e-08, 2.1564709740129473e-10, 1.1193953923793742e-06, 3.434205350649755e-11, 4.421850974267727e-08, 5.323357865627543e-10, 7.135127333413038e-08, 2.6862911894909303e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[3.5868405467986975e-11, 1.390279974478048e-10, 5.9968208176997e-08, 9.52796108322218e-06, 8.024300086617586e-07, 1.1126896879432024e-06, 8.455328384116001e-07, 0.002637791447341442, 7.609258290131038e-08, 4.0096730913319334e-07, 0.0024108835496008396, 9.418944735273271e-09, 1.485275049617485e-07, 2.520800421734748e-07, 4.948814336103169e-08, 0.9949245452880859, 6.511735136882635e-06, 1.3874777993194698e-09, 1.494138132329681e-06, 1.4837324424643583e-10, 3.6820438253926113e-06, 2.5161577266175073e-09, 1.8570571000964264e-06, 5.812178516251265e-10]]
# Predicted class: 15
# predicted class is :  Normal
# ...
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.173538684787426e-12, 2.5948281717758093e-11, 7.713132355036123e-09, 2.3745710677758325e-06, 8.143683061234697e-08, 1.1767496310710612e-08, 6.966168939470663e-07, 2.876714688682114e-07, 7.61747287469916e-09, 1.4481999599524897e-08, 4.911699988952023e-07, 1.5797443908560638e-10, 5.12843989497469e-09, 3.767667777765382e-08, 2.0754549190371563e-09, 0.9999946355819702, 2.848067026661738e-08, 1.71352446121098e-10, 1.118478280659474e-06, 6.7910885248601005e-12, 1.0147568474394575e-07, 1.0972315278579003e-09, 8.803237960819388e-08, 3.437217177548746e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.77409900606429e-10, 4.5726863961981223e-10, 4.890590332706779e-08, 5.3560456763079856e-06, 4.253091105965723e-07, 3.971612750319764e-05, 6.362284329952672e-05, 0.00020284134370740503, 9.594731409379165e-07, 1.5922708485049952e-07, 3.982274211011827e-05, 1.395576543217203e-08, 6.311510958312283e-08, 9.789603439003258e-08, 6.171482169747833e-08, 0.9991445541381836, 5.267026608635206e-06, 3.326698694294805e-09, 5.765893547504675e-06, 9.111490034685588e-11, 0.0004742698511108756, 6.291450915796304e-08, 1.6881816918612458e-05, 5.523969726084488e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.023435973773807e-13, 1.4756014118932903e-11, 8.734928336195935e-09, 7.040409144565274e-08, 1.1242155295576595e-07, 1.4218206612071072e-09, 2.6721055590428477e-08, 2.5272363757267158e-08, 9.59493817731527e-10, 1.7999923329625744e-08, 6.538011803058907e-07, 7.668125162618722e-11, 3.4555069916564207e-09, 2.4274624532694133e-09, 9.288528834971999e-10, 0.9999988079071045, 1.096558754909438e-08, 7.978882138326426e-11, 2.2176661218509253e-07, 1.0747367405750108e-11, 7.547434677235287e-09, 1.137997335254326e-10, 1.4858018815289142e-08, 7.423813647156052e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.081140807243866e-12, 2.163699254487117e-11, 8.543270091365684e-09, 2.4252271941804793e-06, 7.205130003740123e-08, 1.066558130702333e-08, 3.939595103474858e-07, 2.615733194488712e-07, 8.18434120475331e-09, 1.3385829333856236e-08, 4.1243313830818806e-07, 1.3292923706220705e-10, 3.858060981798417e-09, 2.7915390887756075e-08, 2.1188388821258286e-09, 0.9999953508377075, 2.479713145930873e-08, 1.4765459688259597e-10, 8.741624242247781e-07, 6.262014778241065e-12, 1.1989149584223924e-07, 1.2946520522305605e-09, 8.123861761077933e-08, 3.3032915291997256e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.081140807243866e-12, 2.163699254487117e-11, 8.543270091365684e-09, 2.4252271941804793e-06, 7.205130003740123e-08, 1.066558130702333e-08, 3.939595103474858e-07, 2.615733194488712e-07, 8.18434120475331e-09, 1.3385829333856236e-08, 4.1243313830818806e-07, 1.3292923706220705e-10, 3.858060981798417e-09, 2.7915390887756075e-08, 2.1188388821258286e-09, 0.9999953508377075, 2.479713145930873e-08, 1.4765459688259597e-10, 8.741624242247781e-07, 6.262014778241065e-12, 1.1989149584223924e-07, 1.2946520522305605e-09, 8.123861761077933e-08, 3.3032915291997256e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.784350338127297e-08, 3.160628381237984e-08, 6.338128173410951e-07, 0.0003188308037351817, 3.019993982888991e-06, 0.046584244817495346, 0.000294515339192003, 0.0011691260151565075, 5.337201400834601e-06, 4.089006324647926e-06, 0.0001931257575051859, 7.513549917348428e-06, 1.6954772945609875e-06, 3.024269688012282e-07, 3.539440456279408e-07, 0.9511130452156067, 4.6917568397475407e-05, 2.5376618850714294e-07, 2.6691326638683677e-05, 1.36824729324303e-08, 0.00015723565593361855, 3.0287719710031524e-07, 7.26142170606181e-05, 6.675078623175068e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.824331239679073e-13, 1.5257673596780208e-11, 7.551538061534302e-09, 7.186886108456747e-08, 1.2740122201648774e-07, 1.2350539480010525e-09, 1.4799159231415615e-08, 2.001650223348861e-08, 8.43827119290097e-10, 2.2468530147534693e-08, 7.951717861942598e-07, 7.759992648459502e-11, 4.639261863559341e-09, 1.9649453175674125e-09, 8.64805671518809e-10, 0.9999986886978149, 7.356486086962377e-09, 7.47362380315586e-11, 1.962385596243621e-07, 1.533206374360052e-11, 4.206312187449157e-09, 7.826914116826345e-11, 1.1011739076138838e-08, 6.517143769091405e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.508511185913333e-12, 2.3512015251414553e-11, 1.0337871003684995e-08, 7.009147338976618e-06, 6.965666443647933e-08, 7.611989261135932e-09, 2.2052284975870862e-07, 1.3027660372699756e-07, 5.54665113838837e-09, 1.6458857388101933e-08, 3.0462697964139807e-07, 1.4323381369862886e-10, 5.524036339465965e-09, 2.0379404830350722e-08, 1.6939641911406511e-09, 0.9999916553497314, 1.3941300558428793e-08, 2.2241301855796536e-10, 4.756910811920534e-07, 6.01167770078459e-12, 2.298943968526146e-08, 6.315072909046648e-10, 3.4546076221886324e-08, 1.873216165515501e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.508511185913333e-12, 2.3512015251414553e-11, 1.0337871003684995e-08, 7.009147338976618e-06, 6.965666443647933e-08, 7.611989261135932e-09, 2.2052284975870862e-07, 1.3027660372699756e-07, 5.54665113838837e-09, 1.6458857388101933e-08, 3.0462697964139807e-07, 1.4323381369862886e-10, 5.524036339465965e-09, 2.0379404830350722e-08, 1.6939641911406511e-09, 0.9999916553497314, 1.3941300558428793e-08, 2.2241301855796536e-10, 4.756910811920534e-07, 6.01167770078459e-12, 2.298943968526146e-08, 6.315072909046648e-10, 3.4546076221886324e-08, 1.873216165515501e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[8.891919978104568e-10, 1.7592691747836398e-09, 1.0684142637273908e-07, 1.3860991202818695e-05, 6.321677687992633e-07, 0.00017390213906764984, 4.5507640606956556e-05, 0.0002122291480191052, 4.821158654522151e-07, 6.498705715785036e-07, 0.0002556047111283988, 3.9838204202169436e-07, 4.477238064737321e-07, 1.9814301310816518e-07, 6.078973058265547e-08, 0.9992390871047974, 5.299309123074636e-06, 1.53775303601833e-08, 1.2704406799457502e-05, 1.8254536771067364e-09, 2.5033656129380688e-05, 2.743736793320295e-08, 1.3758345630776603e-05, 5.681677350821701e-09]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[7.170296257782982e-13, 1.355203362723989e-11, 6.085631110153145e-09, 8.790281924575538e-08, 9.659007105256023e-08, 1.060501464422714e-09, 2.1722559750969594e-08, 3.271745541155724e-08, 7.638170096413432e-10, 1.8590959882658353e-08, 1.3082993746138527e-06, 6.189623813490641e-11, 4.22439994096635e-09, 3.2999019072832425e-09, 7.330622775469919e-10, 0.9999982118606567, 7.464239892840396e-09, 5.963401300546067e-11, 1.8880672314480762e-07, 1.1743483789572462e-11, 5.262327018584756e-09, 7.179883770858098e-11, 1.3092230410904904e-08, 6.052321838145858e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.612431960150266e-12, 2.9501814186039255e-11, 1.0634991554070439e-08, 1.4249954801925924e-05, 6.48289031346394e-08, 7.78164643833179e-09, 3.5352454119674803e-07, 1.3993579273119394e-07, 5.314937823186483e-09, 1.878893485240951e-08, 3.18595482440287e-07, 1.8004103763402668e-10, 6.949950837054075e-09, 4.6631139838382296e-08, 1.4917936885794347e-09, 0.9999841451644897, 1.4427451233700594e-08, 2.4296120670896926e-10, 5.049421929470554e-07, 5.6081944643793236e-12, 2.1741984213008436e-08, 7.275831603870131e-10, 4.333007908030595e-08, 2.2301539781555135e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.612431960150266e-12, 2.9501814186039255e-11, 1.0634991554070439e-08, 1.4249954801925924e-05, 6.48289031346394e-08, 7.78164643833179e-09, 3.5352454119674803e-07, 1.3993579273119394e-07, 5.314937823186483e-09, 1.878893485240951e-08, 3.18595482440287e-07, 1.8004103763402668e-10, 6.949950837054075e-09, 4.6631139838382296e-08, 1.4917936885794347e-09, 0.9999841451644897, 1.4427451233700594e-08, 2.4296120670896926e-10, 5.049421929470554e-07, 5.6081944643793236e-12, 2.1741984213008436e-08, 7.275831603870131e-10, 4.333007908030595e-08, 2.2301539781555135e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.5519830693099266e-09, 3.6772325184841748e-09, 1.5187272595085233e-07, 7.471581920981407e-05, 1.3108619896229357e-06, 0.0008704537758603692, 0.00019127102859783918, 0.0001857008464867249, 7.843132152629551e-07, 8.858459068505908e-07, 6.205345562193543e-05, 4.157707280683098e-06, 2.8917236249981215e-07, 4.992849085283524e-07, 2.4701785150682554e-07, 0.9983981251716614, 4.878283289144747e-05, 8.956587294051133e-08, 5.455207428894937e-05, 3.5015723653941677e-09, 1.9219927708036266e-05, 1.3369937335028226e-07, 8.655647252453491e-05, 1.617083000837738e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[6.03355364801883e-13, 1.1671851853078952e-11, 8.318265187767793e-09, 6.639078975467783e-08, 1.348964246972173e-07, 1.1455391080161803e-09, 1.384306624885312e-08, 2.2357550477636323e-08, 5.183548590359521e-10, 2.3224862033544014e-08, 9.59570911618357e-07, 7.422609055174334e-11, 4.629970629110858e-09, 3.233664669366476e-09, 8.708488374864487e-10, 0.9999985694885254, 7.40599981341461e-09, 5.039631906234021e-11, 1.6693108761955955e-07, 1.677959854395894e-11, 4.05350375487501e-09, 7.011571878656753e-11, 1.240714020411815e-08, 5.178417070150765e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.2639219058456783e-12, 1.5525934704552213e-11, 8.538475704256143e-09, 2.1907540030952077e-06, 5.241875555839215e-08, 5.214380482954084e-09, 1.4110571555647766e-07, 1.1452650738874581e-07, 3.366579903740785e-09, 1.3613329130635066e-08, 2.6697782118390023e-07, 1.0394816951642127e-10, 3.677637749888163e-09, 3.047724561611176e-08, 1.5247185736200208e-09, 0.9999966621398926, 1.3045696078961555e-08, 1.322617432242268e-10, 4.6526156438631006e-07, 6.036653382029966e-12, 2.462066994723955e-08, 6.000338559353224e-10, 3.850326990573194e-08, 1.35424324532174e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.2639219058456783e-12, 1.5525934704552213e-11, 8.538475704256143e-09, 2.1907540030952077e-06, 5.241875555839215e-08, 5.214380482954084e-09, 1.4110571555647766e-07, 1.1452650738874581e-07, 3.366579903740785e-09, 1.3613329130635066e-08, 2.6697782118390023e-07, 1.0394816951642127e-10, 3.677637749888163e-09, 3.047724561611176e-08, 1.5247185736200208e-09, 0.9999966621398926, 1.3045696078961555e-08, 1.322617432242268e-10, 4.6526156438631006e-07, 6.036653382029966e-12, 2.462066994723955e-08, 6.000338559353224e-10, 3.850326990573194e-08, 1.35424324532174e-10]]
# Predicted class: 5
# predicted class is :  DoS GoldenEye
# Class probabilities: [[5.912722826906247e-07, 2.07499098792141e-07, 4.255299188571371e-07, 2.933982977992855e-05, 2.07510674954392e-06, 0.8486055135726929, 0.002637186087667942, 0.013035635463893414, 2.6298499506083317e-05, 8.603703463450074e-06, 0.00034742089337669313, 0.00013501252396963537, 6.622570253966842e-06, 2.94739503914343e-08, 2.4268463221233105e-06, 0.12417478859424591, 0.000966312363743782, 1.1584368166950298e-06, 1.295593028771691e-05, 2.179848834771292e-08, 0.009705992415547371, 2.3839545519876992e-06, 0.0002988321939483285, 1.2594172460467234e-07]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[6.215622634642148e-13, 1.2829928959512404e-11, 8.586521715869821e-09, 7.193370521463294e-08, 1.2052191777911503e-07, 1.1483763939779124e-09, 1.538111682464205e-08, 2.686413402841481e-08, 5.483706821962642e-10, 1.9139953622016037e-08, 1.1302292932668934e-06, 8.87964909934702e-11, 2.809702692729843e-09, 2.2132327082147185e-09, 1.0425119656432003e-09, 0.9999984502792358, 8.282010632854053e-09, 5.252796461685527e-11, 1.6673807579081767e-07, 1.0648443064809054e-11, 6.624552906231429e-09, 8.372710164072927e-11, 1.3235649909404401e-08, 5.6233056405785575e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.6238087223739992e-12, 1.6264874863614054e-11, 9.916398369114177e-09, 3.0211324428819353e-06, 5.803204672361062e-08, 6.964891330341061e-09, 2.1802287619721028e-07, 3.275140443292912e-07, 4.9558708248298444e-09, 1.2616817812727277e-08, 3.640039096808323e-07, 9.924391863869175e-11, 4.232211026078403e-09, 4.432319045122313e-08, 1.6357944998546259e-09, 0.9999953508377075, 1.2182171715835466e-08, 1.408685390558162e-10, 4.1260543071075517e-07, 5.153105806648961e-12, 6.342383329638324e-08, 9.746690121659185e-10, 5.035069250425295e-08, 1.7771686899870076e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[2.6238087223739992e-12, 1.6264874863614054e-11, 9.916398369114177e-09, 3.0211324428819353e-06, 5.803204672361062e-08, 6.964891330341061e-09, 2.1802287619721028e-07, 3.275140443292912e-07, 4.9558708248298444e-09, 1.2616817812727277e-08, 3.640039096808323e-07, 9.924391863869175e-11, 4.232211026078403e-09, 4.432319045122313e-08, 1.6357944998546259e-09, 0.9999953508377075, 1.2182171715835466e-08, 1.408685390558162e-10, 4.1260543071075517e-07, 5.153105806648961e-12, 6.342383329638324e-08, 9.746690121659185e-10, 5.035069250425295e-08, 1.7771686899870076e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[5.241555456336755e-08, 2.0734541195110978e-08, 1.1617798918450717e-06, 0.00011892400652868673, 2.800270067382371e-06, 0.11497682332992554, 0.0038525883574038744, 0.009662913158535957, 6.510736056952737e-06, 1.7249988104595104e-06, 7.729283242952079e-05, 4.209813141642371e-06, 3.364576059539104e-06, 1.8899461338151013e-06, 9.353699397252058e-07, 0.8704774975776672, 0.00021411650232039392, 2.896850617162272e-07, 0.00010266330355079845, 2.3968771856175408e-08, 0.00035355158615857363, 1.3592326695288648e-06, 0.0001392508129356429, 5.987369178228619e-08]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[7.277384532662634e-13, 1.2076585391429528e-11, 7.933122603276388e-09, 7.306583427180158e-08, 9.76068648128603e-08, 1.4945353843387466e-09, 2.2186444681437933e-08, 2.5194923480853504e-08, 8.871091639051087e-10, 1.7687630915474983e-08, 7.419695293719997e-07, 5.4414257821822076e-11, 3.6378373646783757e-09, 1.8855186301180993e-09, 8.400566353650163e-10, 0.9999988079071045, 6.644764738439335e-09, 6.830403603830248e-11, 2.1648050108069583e-07, 1.3153942345078828e-11, 5.045543538528818e-09, 9.870398248734702e-11, 1.2490032119671923e-08, 6.532289986704853e-11]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.68803468267609e-12, 2.8949110469911332e-11, 1.158576523607735e-08, 3.1062031666806433e-06, 7.191903250713949e-08, 1.1552378609280822e-08, 6.194675279402873e-07, 2.4946132270997623e-07, 6.440902033943985e-09, 1.7908380556264092e-08, 3.776789299081429e-07, 1.993722409387999e-10, 7.741933316651739e-09, 6.688775755492316e-08, 1.6962323767799603e-09, 0.9999946355819702, 1.7893970749582877e-08, 3.8837200122543436e-10, 7.03193563822424e-07, 9.56065348417523e-12, 3.212389643181268e-08, 1.0981506814999875e-09, 5.26825587598978e-08, 2.6907387429275786e-10]]
# Predicted class: 15
# predicted class is :  Normal
# Class probabilities: [[4.68803468267609e-12, 2.8949110469911332e-11, 1.158576523607735e-08, 3.1062031666806433e-06, 7.191903250713949e-08, 1.1552378609280822e-08, 6.194675279402873e-07, 2.4946132270997623e-07, 6.440902033943985e-09, 1.7908380556264092e-08, 3.776789299081429e-07, 1.993722409387999e-10, 7.741933316651739e-09, 6.688775755492316e-08, 1.6962323767799603e-09, 0.9999946355819702, 1.7893970749582877e-08, 3.8837200122543436e-10, 7.03193563822424e-07, 9.56065348417523e-12, 3.212389643181268e-08, 1.0981506814999875e-09, 5.26825587598978e-08, 2.6907387429275786e-10]]

# %%
display_detected_attack_summary(packets_brief, total_packets)
# Out:
# Summary of Predicted Packet Classes:
#                 Attack Type  Packet Count  Percentage (%)
# 0             DoS GoldenEye           571        2.823239
# 1          DoS SlowHTTPTest           286        1.414091
# 2               FTP Patator           248        1.226205
# 3                       Bot            40        0.197775
# 4  Web Attack - Brute Force            20        0.098888
# 5                   Fuzzers             5        0.024722
# 6   Total Packets Processed         20225      100.000000

# %%
total_packets
# Out:
# 20225

# %% [markdown]
# # TPs-ESIR39 Modified

# %%
# Necessary imports
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from scapy.all import *
import pandas as pd # Add pandas here as it's used in display functions
import os # Import the os module

# Model and Tokenizer Loading
tokenizer = AutoTokenizer.from_pretrained("rdpahalavan/bert-network-packet-flow-header-payload")
model = AutoModelForSequenceClassification.from_pretrained("rdpahalavan/bert-network-packet-flow-header-payload")

# Classes
classes = [
 'Analysis',
 'Backdoor',
 'Bot',
 'DDoS',
 'DoS',
 'DoS GoldenEye',
 'DoS Hulk',
 'DoS SlowHTTPTest',
 'DoS Slowloris',
 'Exploits',
 'FTP Patator',
 'Fuzzers',
 'Generic',
 'Heartbleed',
 'Infiltration',
 'Normal',
 'Port Scan',
 'Reconnaissance',
 'SSH Patator',
 'Shellcode',
 'Web Attack - Brute Force',
 'Web Attack - SQL Injection',
 'Web Attack - XSS',
 'Worms']

# Device setup
device = torch.device("cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/321 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/263M [00:00<?, ?B/s]

# %%
# Initialize dictionaries and lists for packet analysis.
packets_brief = {}
forward_packets = {}
backward_packets = {}
protocols = []
protocol_counts = {}

def processing_packet_conversion(packet):
    # Clone the packet for processing without modifying the original.
    packet_2 = packet

    while packet_2:
        # Extract and count protocol layers in the packet.
        layer = packet_2[0]
        if layer.name not in protocol_counts:
            protocol_counts[layer.name] = 0
        else:
            protocol_counts[layer.name] += 1
        protocols.append(layer.name)

        # Break if there are no more payload layers.
        if not layer.payload:
            break
        packet_2 = layer.payload

    # Extract relevant information for feature creation.
    src_ip = packet[IP].src
    dst_ip = packet[IP].dst
    src_port = packet.sport
    dst_port = packet.dport
    ip_length = len(packet[IP])
    ip_ttl = packet[IP].ttl
    ip_tos = packet[IP].tos
    tcp_data_offset = packet[TCP].dataofs
    tcp_flags = packet[TCP].flags

    # Process payload content and create a feature string.
    payload_bytes = bytes(packet.payload)
    payload_length = len(payload_bytes)
    payload_content = payload_bytes.decode('utf-8', 'replace')
    payload_decimal = ' '.join(str(byte) for byte in payload_bytes)
    final_data = "0" + " " + "0" + " " + "195" + " " + "-1" + " " + str(src_port) + " " + str(dst_port) + " " + str(ip_length) + " " + str(payload_length) + " " + str(ip_ttl) + " " + str(ip_tos) + " " + str(tcp_data_offset) + " " + str(int(tcp_flags)) + " " + "-1" + " " + str(payload_decimal)
    return final_data


# Prediction function
text_data = []

def predictingRowsCategory(file_path, filter):
  packets_brief.clear()  # Clear the dictionary tracking packet briefs.

  print("Loading pcap file...")
  pcap = PcapReader(file_path)
  print("Pcap file loaded.")

  print("Couting packets file")
  total_pcap = 0
  for _ in pcap:
      total_pcap += 1
  print("total_pcap (counted): ", total_pcap)

  packets_nbr = 0  # Initialize packet counter.
  with PcapReader(file_path) as pcap:  # Iterate through packets in the pcap file.
    for pkt in pcap:
      if IP in pkt :  # Check for IPv4 packets
        if TCP in pkt:
          input_line = processing_packet_conversion(pkt)  # Process packet data
          if input_line is not None:

            truncated_line = input_line[:1024]  # Limit input length
            tokens = tokenizer(truncated_line, return_tensors="pt")  # Tokenize input
            tokens = {key: value.to(device) for key, value in tokens.items()} # Move tokens to device
            outputs = model(**tokens)  # Pass tokens through the model
            logits = outputs.logits
            probabilities = logits.softmax(dim=1)  # Calculate class probabilities
            predicted_class = torch.argmax(probabilities, dim=1).item()  # Get predicted class index

            predictedAttack = classes[predicted_class]  # Map index to corresponding attack class

            if predictedAttack != "Normal":
              # Update or add count for non-normal packets in packets_brief dictionary
              if predictedAttack not in packets_brief :
                packets_brief[predictedAttack] = 1
              else :
                packets_brief[predictedAttack] += 1

            # Print prediction details
            # print("Predicted class:", predicted_class)
            print("predicted class is : ", classes[predicted_class])
            # print("Class probabilities:", probabilities.tolist())

          packets_nbr += 1  # Increment packet counter
  return packets_nbr

# %%
result = predictingRowsCategory("/content/ftpbrute-kali.pcap", b"")
# Out:
# Loading pcap file...
# Pcap file loaded.
# Couting packets file
# total_pcap (counted):  13910
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# predicted class is :  Normal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-b6a410dbf3b0> in <cell line: 0>()
# ----> 1 result = predictingRowsCategory("/content/ftpbrute-kali.pcap", b"")
#
# <ipython-input-20-cb4d2c9cddad> in predictingRowsCategory(file_path, filter)
#      71             tokens = tokenizer(truncated_line, return_tensors="pt")  # Tokenize input
#      72             tokens = {key: value.to(device) for key, value in tokens.items()} # Move tokens to device
# ---> 73             outputs = model(**tokens)  # Pass tokens through the model
#      74             logits = outputs.logits
#      75             probabilities = logits.softmax(dim=1)  # Calculate class probabilities
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     918         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     919
# --> 920         distilbert_output = self.distilbert(
#     921             input_ids=input_ids,
#     922             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     737                 )
#     738
# --> 739         return self.transformer(
#     740             x=embeddings,
#     741             attn_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     542                 )
#     543             else:
# --> 544                 layer_outputs = layer_module(
#     545                     hidden_state,
#     546                     attn_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     486
#     487         # Feed Forward Network
# --> 488         ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     489         ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     490
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input)
#     420
#     421     def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 422         return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#     423
#     424     def ff_chunk(self, input: torch.Tensor) -> torch.Tensor:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     251         return torch.cat(output_chunks, dim=chunk_dim)
#     252
# --> 253     return forward_fn(*input_tensors)
#     254
#     255
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/modeling_distilbert.py in ff_chunk(self, input)
#     423
#     424     def ff_chunk(self, input: torch.Tensor) -> torch.Tensor:
# --> 425         x = self.lin1(input)
#     426         x = self.activation(x)
#     427         x = self.lin2(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
