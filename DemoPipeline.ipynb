# %% [markdown]
# <a href="https://colab.research.google.com/github/Mc4minta/AIB5-PcapAttackClassifier/blob/main/DemoPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IDK

# %% [markdown]
# ## Shortcut

# %%
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## archive

# %%
# !wget -P CIC-IDS-2017/PCAPs http://cicresearch.ca/CICDataset/CIC-IDS-2017/Dataset/CIC-IDS-2017/PCAPs/Friday-WorkingHours.pcap
# !ls CIC-IDS-2017/PCAPs
# Out:
# --2025-04-29 13:26:04--  http://cicresearch.ca/CICDataset/CIC-IDS-2017/Dataset/CIC-IDS-2017/PCAPs/Friday-WorkingHours.pcap
# Resolving cicresearch.ca (cicresearch.ca)... 205.174.165.80
# Connecting to cicresearch.ca (cicresearch.ca)|205.174.165.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8839309056 (8.2G) [application/vnd.tcpdump.pcap]
# Saving to: ‘CIC-IDS-2017/PCAPs/Friday-WorkingHours.pcap’
#
# Friday-WorkingHours   0%[                    ] 294.75K   422KB/s               ^C
# Friday-WorkingHours.pcap

# %%
# !mv Friday-WorkingHours.pcap data/in
# Out:
# mv: cannot stat 'Friday-WorkingHours.pcap': No such file or directory

# %% [markdown]
# ## Unused

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 79 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Src_Port           60 non-null     int64
#  1   Dst_Port           60 non-null     int64
#  2   Flow_Duration      60 non-null     int64
#  3   Tot_Fwd_Pkts       60 non-null     int64
#  4   Tot_Bwd_Pkts       60 non-null     int64
#  5   TotLen_Fwd_Pkts    60 non-null     float64
#  6   TotLen_Bwd_Pkts    60 non-null     float64
#  7   Fwd_Pkt_Len_Max    60 non-null     float64
#  8   Fwd_Pkt_Len_Min    60 non-null     float64
#  9   Fwd_Pkt_Len_Mean   60 non-null     float64
#  10  Fwd_Pkt_Len_Std    60 non-null     float64
#  11  Bwd_Pkt_Len_Max    60 non-null     float64
#  12  Bwd_Pkt_Len_Min    60 non-null     float64
#  13  Bwd_Pkt_Len_Mean   60 non-null     float64
#  14  Bwd_Pkt_Len_Std    60 non-null     float64
#  15  Flow_Byts/s        60 non-null     float64
# ...

# %%
df.columns
# Out:
# Index(['Src_Port', 'Dst_Port', 'Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts',
#        'TotLen_Fwd_Pkts', 'TotLen_Bwd_Pkts', 'Fwd_Pkt_Len_Max',
#        'Fwd_Pkt_Len_Min', 'Fwd_Pkt_Len_Mean', 'Fwd_Pkt_Len_Std',
#        'Bwd_Pkt_Len_Max', 'Bwd_Pkt_Len_Min', 'Bwd_Pkt_Len_Mean',
#        'Bwd_Pkt_Len_Std', 'Flow_Byts/s', 'Flow_Pkts/s', 'Flow_IAT_Mean',
#        'Flow_IAT_Std', 'Flow_IAT_Max', 'Flow_IAT_Min', 'Fwd_IAT_Tot',
#        'Fwd_IAT_Mean', 'Fwd_IAT_Std', 'Fwd_IAT_Max', 'Fwd_IAT_Min',
#        'Bwd_IAT_Tot', 'Bwd_IAT_Mean', 'Bwd_IAT_Std', 'Bwd_IAT_Max',
#        'Bwd_IAT_Min', 'Fwd_PSH_Flags', 'Bwd_PSH_Flags', 'Fwd_URG_Flags',
#        'Bwd_URG_Flags', 'Fwd_Header_Len', 'Bwd_Header_Len', 'Fwd_Pkts/s',
#        'Bwd_Pkts/s', 'Pkt_Len_Min', 'Pkt_Len_Max', 'Pkt_Len_Mean',
#        'Pkt_Len_Std', 'Pkt_Len_Var', 'FIN_Flag_Cnt', 'SYN_Flag_Cnt',
#        'RST_Flag_Cnt', 'PSH_Flag_Cnt', 'ACK_Flag_Cnt', 'URG_Flag_Cnt',
# ...

# %%
df
# Out:
#     Source_Port  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0         54017                21        2372007                 10
# 1         54018                21        2451845                 10
# 2         54019                21        2062522                  9
# 3         54019                21         404166                  2
# 4         54020                21        1669074                  9
# 5         54020                21         404364                  2
# 6         54021                21        1944855                 10
# 7         54022                21        1885374                 10
# 8         54023                21        1824876                 10
# 9         54024                21        2097766                 10
# 10        54025                21        1809388                 10
# 11        54026                21        2179053                 10
# 12        54027                21        1924635                 10
# ...

# %% [markdown]
# # 1. Convert .pcap files to .csv flow using CICFlowmeter3.0

# %% [markdown]
# ## Download CICFlowMeter3.0

# %%
# !sudo apt-get install libpcap-dev # install libpcap-dev
# !wget https://codeberg.org/iortega/TCPDUMP_and_CICFlowMeter/archive/master:CICFlowMeters/CICFlowMeter-3.0.zip # download CICFlowMeter3.0.zip
# !unzip CICFlowMeter-3.0.zip -d CICFlowMeter-3.0 # Extract CICFlowMeter3.0.zip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libdbus-1-dev libpcap0.8 libpcap0.8-dev
# The following NEW packages will be installed:
#   libdbus-1-dev libpcap-dev libpcap0.8 libpcap0.8-dev
# 0 upgraded, 4 newly installed, 0 to remove and 34 not upgraded.
# Need to get 607 kB of archives.
# After this operation, 2,238 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8 amd64 1.10.1-4ubuntu1.22.04.1 [145 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-dev amd64 1.12.20-2ubuntu4.1 [188 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8-dev amd64 1.10.1-4ubuntu1.22.04.1 [270 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap-dev amd64 1.10.1-4ubuntu1.22.04.1 [3,326 B]
# Fetched 607 kB in 0s (2,041 kB/s)
# ...

# %%
# make data/in and data/out folder
# !mkdir data
# !cd data && mkdir in
# !cd data && mkdir out

# %% [markdown]
# ## Place you .pcap files in data/in directory and run this to convert it

# %%
name = input("Enter you .pcap name: ")
# !mv {name}.pcap data/in
# Out:
# Enter you .pcap name: bruteforce

# %%
# !./CICFlowMeter-3.0/tcpdump_and_cicflowmeter/bin/CICFlowMeter # run the converter
# Out:
# run at:   /content
# app at:   /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# SAVED:    /content
# APP_HOME: /content/CICFlowMeter-3.0/tcpdump_and_cicflowmeter
# ...

# %%
# !mv /content//data/in/{name}.pcap ../../

# %% [markdown]
# # Data importing and Pre processing
#
#
# 1.   replace space in columns name with underscore
# 2.   drop objects type columns
# 3.   rename columns names
# 4.   remove rows with missing and infinite values

# %%
import pandas as pd
import numpy as np
import glob

'''
# import all converted .csv file as dataframe and concat them
csv_files = glob.glob('data/out/*.csv')
dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)'''

# df = pd.read_csv('/content/data/out/bruteforce_ISCX.csv')
# df = pd.read_csv('/content/data/out/portscan_ISCX.csv')
# df = pd.read_csv('/content/data/out/hp_challenge_ISCX.csv')
#df = pd.read_csv('/content/data/out/challenge1_ISCX.csv')
df = pd.read_csv('/content/data/out/' + name + '_ISCX.csv')


# replace space in columns name with underscore
df.columns = df.columns.str.strip().str.replace(' ', '_')

# drop objects type columns
columns_to_drop = [
    'Flow_ID','Src_IP','Dst_IP','Protocol','Timestamp',
]

df = df.drop(columns=columns_to_drop)

# remove rows with missing and infinite values
df.replace([np.inf, -np.inf], np.nan, inplace = True)
df = df.dropna()

# see the head of data
df
# Out:
#     Src_Port  Dst_Port  Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  \
# 0      54017        21        2372007            10             8
# 1      54018        21        2451845            10             8
# 2      54019        21        2062522             9             9
# 3      54019        21         404166             2             2
# 4      54020        21        1669074             9             9
# 5      54020        21         404364             2             2
# 6      54021        21        1944855            10             8
# 7      54022        21        1885374            10             8
# 8      54023        21        1824876            10             8
# 9      54024        21        2097766            10             8
# 10     54025        21        1809388            10             8
# 11     54026        21        2179053            10             8
# 12     54027        21        1924635            10             8
# ...

# %%
columns_mapping = {
    'Src_Port': 'Source_Port',
    'Dst_Port': 'Destination_Port',
    'Flow_Duration': 'Flow_Duration',
    'Tot_Fwd_Pkts': 'Total_Fwd_Packets',
    'Tot_Bwd_Pkts': 'Total_Backward_Packets',
    'TotLen_Fwd_Pkts': 'Total_Length_of_Fwd_Packets',
    'TotLen_Bwd_Pkts': 'Total_Length_of_Bwd_Packets',
    'Fwd_Pkt_Len_Max': 'Fwd_Packet_Length_Max',
    'Fwd_Pkt_Len_Min': 'Fwd_Packet_Length_Min',
    'Fwd_Pkt_Len_Mean': 'Fwd_Packet_Length_Mean',
    'Fwd_Pkt_Len_Std': 'Fwd_Packet_Length_Std',
    'Bwd_Pkt_Len_Max': 'Bwd_Packet_Length_Max',
    'Bwd_Pkt_Len_Min': 'Bwd_Packet_Length_Min',
    'Bwd_Pkt_Len_Mean': 'Bwd_Packet_Length_Mean',
    'Bwd_Pkt_Len_Std': 'Bwd_Packet_Length_Std',
    'Flow_Byts/s': 'Flow_Bytes/s',
    'Flow_Pkts/s': 'Flow_Packets/s',
    'Flow_IAT_Mean': 'Flow_IAT_Mean',
    'Flow_IAT_Std': 'Flow_IAT_Std',
    'Flow_IAT_Max': 'Flow_IAT_Max',
    'Flow_IAT_Min': 'Flow_IAT_Min',
    'Fwd_IAT_Tot': 'Fwd_IAT_Total',
    'Fwd_IAT_Mean': 'Fwd_IAT_Mean',
    'Fwd_IAT_Std': 'Fwd_IAT_Std',
    'Fwd_IAT_Max': 'Fwd_IAT_Max',
    'Fwd_IAT_Min': 'Fwd_IAT_Min',
    'Bwd_IAT_Tot': 'Bwd_IAT_Total',
    'Bwd_IAT_Mean': 'Bwd_IAT_Mean',
    'Bwd_IAT_Std': 'Bwd_IAT_Std',
    'Bwd_IAT_Max': 'Bwd_IAT_Max',
    'Bwd_IAT_Min': 'Bwd_IAT_Min',
    'Fwd_PSH_Flags': 'Fwd_PSH_Flags',
    'Bwd_PSH_Flags': 'Bwd_PSH_Flags',
    'Fwd_URG_Flags': 'Fwd_URG_Flags',
    'Bwd_URG_Flags': 'Bwd_URG_Flags',
    'Fwd_Header_Len': 'Fwd_Header_Length',
    'Bwd_Header_Len': 'Bwd_Header_Length',
    'Fwd_Pkts/s': 'Fwd_Packets/s',
    'Bwd_Pkts/s': 'Bwd_Packets/s',
    'Pkt_Len_Min': 'Min_Packet_Length',
    'Pkt_Len_Max': 'Max_Packet_Length',
    'Pkt_Len_Mean': 'Packet_Length_Mean',
    'Pkt_Len_Std': 'Packet_Length_Std',
    'Pkt_Len_Var': 'Packet_Length_Variance',
    'FIN_Flag_Cnt': 'FIN_Flag_Count',
    'SYN_Flag_Cnt': 'SYN_Flag_Count',
    'RST_Flag_Cnt': 'RST_Flag_Count',
    'PSH_Flag_Cnt': 'PSH_Flag_Count',
    'ACK_Flag_Cnt': 'ACK_Flag_Count',
    'URG_Flag_Cnt': 'URG_Flag_Count',
    'CWE_Flag_Count': 'CWE_Flag_Count',
    'ECE_Flag_Cnt': 'ECE_Flag_Count',
    'Down/Up_Ratio': 'Down/Up_Ratio',
    'Pkt_Size_Avg': 'Average_Packet_Size',
    'Fwd_Seg_Size_Avg': 'Avg_Fwd_Segment_Size',
    'Bwd_Seg_Size_Avg': 'Avg_Bwd_Segment_Size',
    'Fwd_Byts/b_Avg': 'Fwd_Avg_Bytes/Bulk',
    'Fwd_Pkts/b_Avg': 'Fwd_Avg_Packets/Bulk',
    'Fwd_Blk_Rate_Avg': 'Fwd_Avg_Bulk_Rate',
    'Bwd_Byts/b_Avg': 'Bwd_Avg_Bytes/Bulk',
    'Bwd_Pkts/b_Avg': 'Bwd_Avg_Packets/Bulk',
    'Bwd_Blk_Rate_Avg': 'Bwd_Avg_Bulk_Rate',
    'Subflow_Fwd_Pkts': 'Subflow_Fwd_Packets',
    'Subflow_Fwd_Byts': 'Subflow_Fwd_Bytes',
    'Subflow_Bwd_Pkts': 'Subflow_Bwd_Packets',
    'Subflow_Bwd_Byts': 'Subflow_Bwd_Bytes',
    'Init_Fwd_Win_Byts': 'Init_Win_bytes_forward',
    'Init_Bwd_Win_Byts': 'Init_Win_bytes_backward',
    'Fwd_Act_Data_Pkts': 'act_data_pkt_fwd',
    'Fwd_Seg_Size_Min': 'min_seg_size_forward',
    'Active_Mean': 'Active_Mean',
    'Active_Std': 'Active_Std',
    'Active_Max': 'Active_Max',
    'Active_Min': 'Active_Min',
    'Idle_Mean': 'Idle_Mean',
    'Idle_Std': 'Idle_Std',
    'Idle_Max': 'Idle_Max',
    'Idle_Min': 'Idle_Min'
}

# %%
df = df.rename(columns=columns_mapping)
df = df.dropna()
df.head()
# Out:
#    Source_Port  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0        54017                21        2372007                 10
# 1        54018                21        2451845                 10
# 2        54019                21        2062522                  9
# 3        54019                21         404166                  2
# 4        54020                21        1669074                  9
#
#    Total_Backward_Packets  Total_Length_of_Fwd_Packets  \
# 0                       8                         24.0
# 1                       8                         24.0
# 2                       9                         24.0
# 3                       2                          0.0
# 4                       9                         24.0
#
#    Total_Length_of_Bwd_Packets  Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  \
# 0                        137.0                   10.0                    0.0
# ...

# %% [markdown]
# # 2. Predict with machine learning model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
model = joblib.load('/content/drive/MyDrive/Share to Mc4/AIBuilders5-MiN/GeneratedLabelFlow.pkl')

# %%
X_test = df.drop('Label', axis=1)
y_pred = df['Label']

# %%
y_pred = model.predict(X_test)

# %%
predictions = pd.DataFrame({'Label': y_pred})
predictions.value_counts()
# Out:
# Label
# Benign    60
# Name: count, dtype: int64

# %% [markdown]
# # 3. Visualize output

# %%
# prompt: Plot Labels as bar graph

# Assuming 'predictions' DataFrame contains the predicted labels
label_counts = predictions['Label'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(label_counts.index, label_counts.values)
plt.xlabel("Labels")
plt.ylabel("Frequency")
plt.title("Predicted Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'predictions' DataFrame contains the predicted labels
label_counts = predictions['Label'].value_counts()

# Calculate percentage for each label
total_samples = label_counts.sum()
label_percentages = (label_counts / total_samples) * 100

# Create a list of colors for each label
colors = ['grey' if label == 'Benign' else 'lightcoral' for label in label_percentages.index]

plt.figure(figsize=(10, 6))
plt.bar(label_percentages.index, label_percentages.values, color=colors)
plt.xlabel("Labels")
plt.ylabel("Percentage")
plt.title("Predicted Label Distribution")

# Add percentage labels on top of the bars
for i, v in enumerate(label_percentages.values):
    plt.text(i, v, f'{v:.2f}%', ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'predictions' DataFrame contains the predicted labels
label_counts = predictions['Label'].value_counts()

# Filter out 'Benign' label
label_counts = label_counts[label_counts.index != 'Benign']

# Calculate percentage for each label
total_samples = label_counts.sum()
label_percentages = (label_counts / total_samples) * 100

# Create a list of colors for each label
# Assign 'lightcoral' to all labels
colors = ['lightcoral' for label in label_percentages.index]


plt.figure(figsize=(10, 6))
plt.bar(label_percentages.index, label_percentages.values, color=colors)
plt.xlabel("Labels")
plt.ylabel("Percentage")
plt.title("Predicted Label Distribution (excluding Benign)")

# Add percentage labels on top of the bars
for i, v in enumerate(label_percentages.values):
    plt.text(i, v, f'{v:.2f}%', ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'predictions' DataFrame contains the predicted labels
label_counts = predictions['Label'].value_counts()

# Filter out 'Benign' label
label_counts = label_counts[label_counts.index != 'Benign']

# Create a list of colors for each label
# Assign 'lightcoral' to all labels
colors = ['lightcoral' for label in label_counts.index]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title("Predicted Label Distribution (excluding Benign)")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'predictions' DataFrame contains the predicted labels
label_counts = predictions['Label'].value_counts()

# Check if only 'Benign' label is present
if label_counts.index.equals(pd.Index(['Benign'])):
    # Create a figure and display "No Attack found"
    plt.figure(figsize=(8, 8))
    plt.text(0.5, 0.5, "No Attack found", ha='center', va='center', fontsize=20)
    plt.axis('off')  # Hide axes
    plt.show()
else:
    # Calculate total including 'Benign'
    total_samples = label_counts.sum()

    # Filter out 'Benign' label for the pie chart
    label_counts_pie = label_counts[label_counts.index != 'Benign']

    # Create a list of colors for each label
    colors = ['lightcoral' for label in label_counts_pie.index]

    # Create pie chart, using original total for percentage calculation
    plt.figure(figsize=(8, 8))
    plt.pie(label_counts_pie, labels=label_counts_pie.index,
            autopct=lambda p: '{:.1f}%'.format(p * total_samples / 100 / total_samples * 100),
            startangle=90, colors=colors)
    plt.title("Predicted Label Distribution (excluding Benign)")
    plt.show()
